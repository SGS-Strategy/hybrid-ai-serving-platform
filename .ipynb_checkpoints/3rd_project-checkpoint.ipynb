# %%
pip install numpy pandas scipy scikit-learn torch matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: pip is configured with locations that require TLS/SSL, however the ssl module in Python is not available.

# %%
import numpy as np
import pandas as pd
import random
import seaborn as sns
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# #### **전처리 전 데이터 구조**
# ![image.png](attachment:fea0c297-a4e6-4504-bfb4-55a49b2abd21.png)

# %% [markdown]
# #### **전처리 후 데이터 구조**
# ![image.png](attachment:6e143430-3ff4-43cd-857d-0315fdaa5646.png)

# %%
import os
os.chdir('C:/Users/user')
print(os.getcwd())          # 현재 위치
print(os.listdir())         # 현재 폴더 파일 목록
# Out:
# C:\Users\user
# ...

# %%
# 데이터 불러오기
sensor1_g1 = pd.read_csv('Downloads/data/g1_sensor1.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])
sensor2_g1 = pd.read_csv('Downloads/data/g1_sensor2.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])
sensor3_g1 = pd.read_csv('Downloads/data/g1_sensor3.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])
sensor4_g1 = pd.read_csv('Downloads/data/g1_sensor4.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])

sensor1_g2 = pd.read_csv('Downloads/data/g2_sensor1.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])
sensor2_g2 = pd.read_csv('Downloads/data/g2_sensor2.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])
sensor3_g2 = pd.read_csv('Downloads/data/g2_sensor3.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])
sensor4_g2 = pd.read_csv('Downloads/data/g2_sensor4.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])

# %%
sensor1_g1
# Out:
#               time    normal     type1     type2     type3
# 0         0.000000 -0.853307 -3.464579  0.555219  3.919664
# 1         0.000736 -0.740463 -2.448986 -0.234687  4.145351
# 2         0.001472 -0.138630 -1.922383 -0.009000  2.941685
# 3         0.002208  0.049443 -0.906790 -0.272301  2.603155
# 4         0.002944 -0.289088 -0.568259 -0.986978  1.361874
# ...            ...       ...       ...       ...       ...
# 190213  139.996768 -1.156354 -2.696750  0.844491 -2.109427
# 190214  139.997504 -0.930666 -1.380241  0.919720 -2.222270
# 190215  139.998240 -0.554521 -2.132532  0.731647 -2.109427
# 190216  139.998976 -1.419655 -2.433448  1.183022 -3.087405
# 190217  139.999712 -0.441677 -2.245376  1.333480 -2.184656
#
# [190218 rows x 5 columns]

# %%
# 그룹당 4개의 센서로부터 140초간 수집한 데이터의 크기
# 열 값이 다른 이유는 각 센서의 샘플링 속도가 다르기 때문
print('sensor1_group1의 데이터 크기', sensor1_g1.shape)
print('sensor2_group1의 데이터 크기', sensor2_g1.shape)
print('sensor3_group1의 데이터 크기', sensor3_g1.shape)
print('sensor4_group1의 데이터 크기', sensor4_g1.shape)

print('sensor1_group2의 데이터 크기', sensor1_g2.shape)
print('sensor2_group2의 데이터 크기', sensor2_g2.shape)
print('sensor3_group2의 데이터 크기', sensor3_g2.shape)
print('sensor4_group2의 데이터 크기', sensor4_g2.shape)
# Out:
# sensor1_group1의 데이터 크기 (190218, 5)
# sensor2_group1의 데이터 크기 (184211, 5)
# sensor3_group1의 데이터 크기 (196079, 5)
# sensor4_group1의 데이터 크기 (183969, 5)
# sensor1_group2의 데이터 크기 (190218, 5)
# sensor2_group2의 데이터 크기 (184211, 5)
# sensor3_group2의 데이터 크기 (196079, 5)
# sensor4_group2의 데이터 크기 (183969, 5)

# %%
# 전처리 1 - 계측 시간의 동일화를 위한 데이터 선형보간
from scipy import interpolate

x_new = np.arange(0, 140, 0.001)

def interpolate_sensor(sensor, x_new):
    y_new = []
    for item in ['normal', 'type1', 'type2', 'type3']:
        f_linear = interpolate.interp1d(sensor['time'], sensor[item], kind='linear')
        y_new.append(f_linear(x_new))
    return pd.DataFrame(np.array(y_new).T, columns=['normal', 'type1', 'type2', 'type3'])

sensor1_g1 = interpolate_sensor(sensor1_g1, x_new)
sensor2_g1 = interpolate_sensor(sensor2_g1, x_new)
sensor3_g1 = interpolate_sensor(sensor3_g1, x_new)
sensor4_g1 = interpolate_sensor(sensor4_g1, x_new)

sensor1_g2 = interpolate_sensor(sensor1_g2, x_new)
sensor2_g2 = interpolate_sensor(sensor2_g2, x_new)
sensor3_g2 = interpolate_sensor(sensor3_g2, x_new)
sensor4_g2 = interpolate_sensor(sensor4_g2, x_new)

# %%
# 보간 결과 데이터 사이즈는 (140000, 4) 가 됨
sensor1_g1
# Out:
#           normal     type1     type2     type3
# 0      -0.853307 -3.464579  0.555219  3.919664
# 1      -0.524588 -2.260096 -0.153734  3.713601
# 2      -0.003708 -1.193805 -0.197890  2.698827
# 3      -0.297674 -0.490986 -0.972668  1.338978
# 4      -0.091203  0.790771 -0.913384  0.701167
# ...          ...       ...       ...       ...
# 139995 -1.057411 -1.389236  0.664186 -1.498190
# 139996 -0.513635 -1.368793  1.050553 -0.982626
# 139997 -1.085213 -2.281763  0.868204 -2.144997
# 139998 -0.677177 -1.887220  0.792975 -2.146224
# 139999 -1.387764 -2.427315  1.187928 -3.057968
#
# [140000 rows x 4 columns]

# %%
# 실제 취득된 형태로 데이터 재조정
normal_g1 = pd.concat([sensor1_g1['normal'], sensor2_g1['normal'], sensor3_g1['normal'], sensor4_g1['normal']], axis=1)
type1_g1  = pd.concat([sensor1_g1['type1'],  sensor2_g1['type1'],  sensor3_g1['type1'],  sensor4_g1['type1']],  axis=1)
type2_g1  = pd.concat([sensor1_g1['type2'],  sensor2_g1['type2'],  sensor3_g1['type2'],  sensor4_g1['type2']],  axis=1)
type3_g1  = pd.concat([sensor1_g1['type3'],  sensor2_g1['type3'],  sensor3_g1['type3'],  sensor4_g1['type3']],  axis=1)

normal_g2 = pd.concat([sensor1_g2['normal'], sensor2_g2['normal'], sensor3_g2['normal'], sensor4_g2['normal']], axis=1)
type1_g2  = pd.concat([sensor1_g2['type1'],  sensor2_g2['type1'],  sensor3_g2['type1'],  sensor4_g2['type1']],  axis=1)
type2_g2  = pd.concat([sensor1_g2['type2'],  sensor2_g2['type2'],  sensor3_g2['type2'],  sensor4_g2['type2']],  axis=1)
type3_g2  = pd.concat([sensor1_g2['type3'],  sensor2_g2['type3'],  sensor3_g2['type3'],  sensor4_g2['type3']],  axis=1)

normal_g1.columns = type1_g1.columns = type2_g1.columns = type3_g1.columns = ['s1', 's2', 's3', 's4']
normal_g2.columns = type1_g2.columns = type2_g2.columns = type3_g2.columns = ['s1', 's2', 's3', 's4']

# %%
normal_g1
# Out:
#               s1        s2        s3        s4
# 0      -0.853307  0.048823 -0.437626 -1.116226
# 1      -0.524588 -0.029477 -0.149817 -0.659694
# 2      -0.003708 -0.004751  0.280889 -0.857345
# 3      -0.297674  0.009673 -0.303281 -0.685318
# 4      -0.091203  0.096215 -0.320263 -0.303108
# ...          ...       ...       ...       ...
# 139995 -1.057411  0.587429  0.275044  0.289837
# 139996 -0.513635 -0.137874 -0.045973  0.131462
# 139997 -1.085213  0.002242 -0.164593 -0.087380
# 139998 -0.677177 -0.308897  0.288252  1.319862
# 139999 -1.387764 -0.731303  0.395425 -0.125739
#
# [140000 rows x 4 columns]

# %%
# 데이터 시각화 (시간에 따른 계측값)
# class 1 : 정상상태 / class 2 : 비정상 상태
fig, axes = plt.subplots(1, 2, figsize=(20, 4))

axes[0].scatter(range(0, 300), normal_g1['s1'][:300], label="class = " + str(1), marker='o', s=5)
axes[0].scatter(range(0, 300), type1_g1['s1'][:300],  label="class = " + str(2), marker='o', s=5)
axes[0].legend(loc="lower right")
axes[0].set_xlabel("Sensor", fontsize=15)
axes[0].set_ylabel("Sensor Value", fontsize=15)
axes[0].set_title("Group 1", fontsize=15)

axes[1].scatter(range(0, 300), normal_g2['s1'][:300], label="class = " + str(1), marker='o', s=5)
axes[1].scatter(range(0, 300), type1_g2['s1'][:300],  label="class = " + str(2), marker='o', s=5)
axes[1].legend(loc="lower right")
axes[1].set_xlabel("Sensor", fontsize=15)
axes[1].set_ylabel("Sensor Value", fontsize=15)
axes[1].set_title("Group 2", fontsize=15)

plt.tight_layout()
plt.show()
plt.close()

# %%
# 데이터의 센서별 상관관계 (Group 1)
print("Group 1")
display(normal_g1.corr())

# 데이터의 센서별 상관관계 (Group 2)
print("Group 2")
display(normal_g2.corr())
# Out:
# Group 1
#           s1        s2        s3        s4
# s1  1.000000 -0.007093  0.004297 -0.003377
# s2 -0.007093  1.000000 -0.002992  0.111121
# s3  0.004297 -0.002992  1.000000 -0.006434
# s4 -0.003377  0.111121 -0.006434  1.000000
# Group 2
#           s1        s2        s3        s4
# s1  1.000000  0.001302 -0.003162 -0.007441
# s2  0.001302  1.000000  0.018414 -0.046489
# s3 -0.003162  0.018414  1.000000  0.002070
# s4 -0.007441 -0.046489  0.002070  1.000000

# %%
# 데이터 상관관계 시각화
names = ['s1', 's2', 's3', 's4']

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Group 1
cm_g1 = np.corrcoef(normal_g1[names].values.T)
sns.set(font_scale=0.8)
sns.heatmap(cm_g1, annot=True, square=True, fmt='.2f', annot_kws={'size': 10},
            yticklabels=names, xticklabels=names, cmap=plt.cm.Blues, ax=axes[0])
axes[0].set_title("Group 1", fontsize=15)

# Group 2
cm_g2 = np.corrcoef(normal_g2[names].values.T)
sns.heatmap(cm_g2, annot=True, square=True, fmt='.2f', annot_kws={'size': 10},
            yticklabels=names, xticklabels=names, cmap=plt.cm.Blues, ax=axes[1])
axes[1].set_title("Group 2", fontsize=15)

plt.tight_layout()
plt.show()

# %%
# 전처리 2 - 데이터 필터링 (노이즈 제거)
M = 15

def moving_avg(series, M):
    result = np.convolve(series, np.ones(M), 'valid') / M
    return result.reshape(len(result), 1)

# Group 1
normal_s1_g1 = moving_avg(normal_g1['s1'], M)
normal_s2_g1 = moving_avg(normal_g1['s2'], M)
normal_s3_g1 = moving_avg(normal_g1['s3'], M)
normal_s4_g1 = moving_avg(normal_g1['s4'], M)

type1_s1_g1 = moving_avg(type1_g1['s1'], M)
type1_s2_g1 = moving_avg(type1_g1['s2'], M)
type1_s3_g1 = moving_avg(type1_g1['s3'], M)
type1_s4_g1 = moving_avg(type1_g1['s4'], M)

type2_s1_g1 = moving_avg(type2_g1['s1'], M)
type2_s2_g1 = moving_avg(type2_g1['s2'], M)
type2_s3_g1 = moving_avg(type2_g1['s3'], M)
type2_s4_g1 = moving_avg(type2_g1['s4'], M)

type3_s1_g1 = moving_avg(type3_g1['s1'], M)
type3_s2_g1 = moving_avg(type3_g1['s2'], M)
type3_s3_g1 = moving_avg(type3_g1['s3'], M)
type3_s4_g1 = moving_avg(type3_g1['s4'], M)

# Group 2
normal_s1_g2 = moving_avg(normal_g2['s1'], M)
normal_s2_g2 = moving_avg(normal_g2['s2'], M)
normal_s3_g2 = moving_avg(normal_g2['s3'], M)
normal_s4_g2 = moving_avg(normal_g2['s4'], M)

type1_s1_g2 = moving_avg(type1_g2['s1'], M)
type1_s2_g2 = moving_avg(type1_g2['s2'], M)
type1_s3_g2 = moving_avg(type1_g2['s3'], M)
type1_s4_g2 = moving_avg(type1_g2['s4'], M)

type2_s1_g2 = moving_avg(type2_g2['s1'], M)
type2_s2_g2 = moving_avg(type2_g2['s2'], M)
type2_s3_g2 = moving_avg(type2_g2['s3'], M)
type2_s4_g2 = moving_avg(type2_g2['s4'], M)

type3_s1_g2 = moving_avg(type3_g2['s1'], M)
type3_s2_g2 = moving_avg(type3_g2['s2'], M)
type3_s3_g2 = moving_avg(type3_g2['s3'], M)
type3_s4_g2 = moving_avg(type3_g2['s4'], M)

# concatenate
normal_temp_g1 = np.concatenate((normal_s1_g1, normal_s2_g1, normal_s3_g1, normal_s4_g1), axis=1)
type1_temp_g1  = np.concatenate((type1_s1_g1,  type1_s2_g1,  type1_s3_g1,  type1_s4_g1),  axis=1)
type2_temp_g1  = np.concatenate((type2_s1_g1,  type2_s2_g1,  type2_s3_g1,  type2_s4_g1),  axis=1)
type3_temp_g1  = np.concatenate((type3_s1_g1,  type3_s2_g1,  type3_s3_g1,  type3_s4_g1),  axis=1)

normal_temp_g2 = np.concatenate((normal_s1_g2, normal_s2_g2, normal_s3_g2, normal_s4_g2), axis=1)
type1_temp_g2  = np.concatenate((type1_s1_g2,  type1_s2_g2,  type1_s3_g2,  type1_s4_g2),  axis=1)
type2_temp_g2  = np.concatenate((type2_s1_g2,  type2_s2_g2,  type2_s3_g2,  type2_s4_g2),  axis=1)
type3_temp_g2  = np.concatenate((type3_s1_g2,  type3_s2_g2,  type3_s3_g2,  type3_s4_g2),  axis=1)

# %%
# 전처리 3 - 데이터 정규화
from sklearn.preprocessing import MinMaxScaler

scaler_g1 = MinMaxScaler()
scaler_g1.fit(normal_g1)
normal_g1_scaled = scaler_g1.transform(normal_temp_g1)
type1_g1_scaled  = scaler_g1.transform(type1_temp_g1)
type2_g1_scaled  = scaler_g1.transform(type2_temp_g1)
type3_g1_scaled  = scaler_g1.transform(type3_temp_g1)

scaler_g2 = MinMaxScaler()
scaler_g2.fit(normal_g2)
normal_g2_scaled = scaler_g2.transform(normal_temp_g2)
type1_g2_scaled  = scaler_g2.transform(type1_temp_g2)
type2_g2_scaled  = scaler_g2.transform(type2_temp_g2)
type3_g2_scaled  = scaler_g2.transform(type3_temp_g2)
# Out:
# C:\Users\user\anaconda3\envs\KAMP\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\user\anaconda3\envs\KAMP\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\user\anaconda3\envs\KAMP\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\user\anaconda3\envs\KAMP\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   "X does not have valid feature names, but"
# ...

# %%
# 데이터가 (0, 1)로 정규화됨
print(normal_g1_scaled)
print('------------------------------------------------')
print('normal g1 data size = ', normal_g1_scaled.shape)

print(normal_g2_scaled)
print('------------------------------------------------')
print('normal g2 data size = ', normal_g2_scaled.shape)
# Out:
# [[0.57598822 0.50553898 0.56439491 0.44551164]
#  [0.60960317 0.50513674 0.58169332 0.44848001]
#  [0.62990663 0.5047345  0.59547186 0.46260474]
#  ...
#  [0.51874981 0.50106998 0.60999194 0.50715712]
#  [0.49713039 0.51588928 0.6074125  0.53093987]
#  [0.45708747 0.52025039 0.60349765 0.53976513]]
# ------------------------------------------------
# normal g1 data size =  (139986, 4)
# [[0.48984203 0.50308872 0.53536786 0.55055298]
#  [0.489891   0.49283803 0.53865522 0.55085156]
#  [0.48968534 0.49138998 0.51177849 0.56190125]
#  ...
#  [0.50980233 0.49636075 0.5493225  0.52765332]
#  [0.50407806 0.50946943 0.55936456 0.5193669 ]
#  [0.49892182 0.52455966 0.55633615 0.50915935]]
# ------------------------------------------------
# normal g2 data size =  (139986, 4)

# %%
# 숫자 확인의 효율성을 위해 데이터 사이즈 (100000, 4)로 조정

normal = normal[30000:130000][:]
type1  = type1[30000:130000][:]
type2  = type2[30000:130000][:]
type3  = type3[30000:130000][:]

print(normal)
print('------------------------------------------------')
print('normal data size = ', normal.shape)
# Out:
# [[0.42588581 0.56360116 0.59076635 0.45259554]
#  [0.39980512 0.54859132 0.57699856 0.4486034 ]
#  [0.38031149 0.54190146 0.57998374 0.44726771]
#  ...
#  [0.48028648 0.53048363 0.62114742 0.51024851]
#  [0.44818273 0.53444251 0.62103995 0.49126006]
#  [0.42832757 0.5501298  0.60917718 0.47827626]]
# ------------------------------------------------
# normal data size =  (100000, 4)

# %%
# 데이터 분배 (학습/검증/테스트)
# 학습 : 검증 : 테스트 = 6 : 2 : 2
normal_train = normal[:60000];  normal_valid = normal[60000:80000];  normal_test = normal[80000:]
type1_train  = type1[:60000];   type1_valid  = type1[60000:80000];   type1_test  = type1[80000:]
type2_train  = type2[:60000];   type2_valid  = type2[60000:80000];   type2_test  = type2[80000:]
type3_train  = type3[:60000];   type3_valid  = type3[60000:80000];   type3_test  = type3[80000:]

train = np.concatenate((normal_train, type1_train, type2_train, type3_train))
valid = np.concatenate((normal_valid, type1_valid, type2_valid, type3_valid))
test  = np.concatenate((normal_test,  type1_test,  type2_test,  type3_test))

print("train data의 형태:", train.shape)
print("valid data의 형태:", valid.shape)
print(" test data의 형태:", test.shape)
# Out:
# train data의 형태: (240000, 4)
# valid data의 형태: (80000, 4)
#  test data의 형태: (80000, 4)

# %%
# 데이터 라벨링
# normal = 0 / type 1 = 1 / type 2 = 2 / type 3 = 3

train_label = np.concatenate((np.full((60000, 1), 0), np.full((60000, 1), 1), np.full((60000, 1), 2), np.full((60000, 1), 3)))
valid_label = np.concatenate((np.full((20000, 1), 0), np.full((20000, 1), 1), np.full((20000, 1), 2), np.full((20000, 1), 3)))
test_label  = np.concatenate((np.full((20000, 1), 0), np.full((20000, 1), 1), np.full((20000, 1), 2), np.full((20000, 1), 3)))

# %%
# 데이터 뒤섞기
# 순서에 의존하지 않고 임의의 데이터가 입력되는 것으로 간주하기 위함

idx = np.arange(train.shape[0])
np.random.shuffle(idx)
train       = train[idx]
train_label = train_label[idx]

idx_v = np.arange(valid.shape[0])
np.random.shuffle(idx_v)
valid       = valid[idx_v]
valid_label = valid_label[idx_v]

idx_t = np.arange(test.shape[0])
np.random.shuffle(idx_t)
test       = test[idx_t]
test_label = test_label[idx_t]

# %%
# 데이터 형태 변환 (array -> tensor 형태)

x_train = torch.from_numpy(train).float()
y_train = torch.from_numpy(train_label).float().T[0]

x_valid = torch.from_numpy(valid).float()
y_valid = torch.from_numpy(valid_label).float().T[0]

x_test = torch.from_numpy(test).float()
y_test = torch.from_numpy(test_label).float().T[0]

print("변경 전")
train

print("변경 후")
x_train
# Out:
# 변경 전
# 변경 후
# tensor([[0.6599, 0.5349, 0.5639, 0.4414],
#         [0.3831, 0.2662, 0.5691, 0.5970],
#         [0.6958, 0.5171, 0.5781, 0.5030],
#         ...,
#         [0.8897, 0.5963, 0.5751, 0.7591],
#         [0.6093, 0.5395, 0.6125, 0.5559],
#         [0.5484, 0.5358, 0.5908, 0.4371]])

# %%
# 데이터 묶기

from torch.utils.data import TensorDataset, DataLoader

train          = TensorDataset(x_train, y_train)
train_dataloader = DataLoader(train, batch_size=5000, shuffle=True)

valid          = TensorDataset(x_valid, y_valid)
valid_dataloader = DataLoader(valid, batch_size=len(x_valid), shuffle=False)

test           = TensorDataset(x_test, y_test)
test_dataloader  = DataLoader(test,  batch_size=len(x_valid), shuffle=False)

# %%
# 심층신경망(DNN)
# 모델 내 은닉층을 많이 늘려서 학습의 결과를 향상시키는 방법

class KAMP_DNN(nn.Module):
    def __init__(self):
        super(KAMP_DNN, self).__init__()
        self.layer1  = nn.Linear(in_features=4,   out_features=100)
        self.layer2  = nn.Linear(in_features=100, out_features=100)
        self.layer3  = nn.Linear(in_features=100, out_features=100)
        self.layer4  = nn.Linear(in_features=100, out_features=4)
        self.dropout = nn.Dropout(0.2)
        self.relu    = nn.ReLU()

    def forward(self, input):
        out = self.layer1(input)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.layer2(out)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.layer3(out)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.layer4(out)
        return out

model_check = KAMP_DNN()
print(model_check)
# Out:
# KAMP_DNN(
#   (layer1): Linear(in_features=4, out_features=100, bias=True)
#   (layer2): Linear(in_features=100, out_features=100, bias=True)
#   (layer3): Linear(in_features=100, out_features=100, bias=True)
#   (layer4): Linear(in_features=100, out_features=4, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (relu): ReLU()
# )

# %%
# 모델 학습

def train_model(model, criterion, optimizer, num_epochs, train_dataloader, PATH):
    loss_values   = []
    loss_values_v = []
    check         = 0
    accuracy_past = 0

    for epoch in range(1, num_epochs + 1):

        #---------------------- 모델 학습 ----------------------#
        model.train()
        batch_number = 0
        running_loss = 0.0

        for batch_idx, samples in enumerate(train_dataloader):
            x_train, y_train = samples
            optimizer.zero_grad()
            y_hat = model.forward(x_train)
            loss  = criterion(y_hat, y_train.long())
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            batch_number += 1

        loss_values.append(running_loss / batch_number)

        #---------------------- 모델 검증 ----------------------#
        model.eval()
        accuracy = 0.0
        total    = 0.0

        for batch_idx, data in enumerate(valid_dataloader):
            x_valid, y_valid = data
            v_hat  = model.forward(x_valid)
            v_loss = criterion(v_hat, y_valid.long())
            _, predicted = torch.max(v_hat.data, 1)
            total    += y_valid.size(0)
            accuracy += (predicted == y_valid).sum().item()

        loss_values_v.append(v_loss.item())
        accuracy = accuracy / total

        #---------------- Check for early stopping --------------#
        if epoch % 1 == 0:
            print('[Epoch {}/{}] [Train_Loss: {:.6f} / Valid_Loss: {:.6f}]'.format(
                epoch, num_epochs, loss.item(), v_loss.item()))
            print('[Epoch {}/{}] [Accuracy : {:.6f}]'.format(
                epoch, num_epochs, accuracy))

        if accuracy_past > accuracy:
            check += 1
        else:
            check = 0
        accuracy_past = accuracy

        if check > 50:
            print('This is time to do early stopping')
            break

    torch.save(model, PATH + 'model.pt')
    return loss_values, loss_values_v

# %%
import os
os.makedirs('save/DNN/', exist_ok=True)

# %%
# DNN 모델 학습

DNN_model  = KAMP_DNN()
num_epochs = 200
criterion  = nn.CrossEntropyLoss()
optimizer  = torch.optim.Adam(DNN_model.parameters())
PATH       = 'save/DNN/'

DNN_loss_values, DNN_loss_values_v = train_model(DNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)
# Out:
# [Epoch 1/200] [Train_Loss: 1.143788 / Valid_Loss: 1.088121]
# [Epoch 1/200] [Accuracy : 0.437462]
# [Epoch 2/200] [Train_Loss: 0.933101 / Valid_Loss: 0.874334]
# [Epoch 2/200] [Accuracy : 0.489100]
# [Epoch 3/200] [Train_Loss: 0.873313 / Valid_Loss: 0.848618]
# [Epoch 3/200] [Accuracy : 0.503138]
# [Epoch 4/200] [Train_Loss: 0.859363 / Valid_Loss: 0.838684]
# [Epoch 4/200] [Accuracy : 0.496925]
# [Epoch 5/200] [Train_Loss: 0.864665 / Valid_Loss: 0.829438]
# [Epoch 5/200] [Accuracy : 0.515713]
# [Epoch 6/200] [Train_Loss: 0.849747 / Valid_Loss: 0.820813]
# [Epoch 6/200] [Accuracy : 0.550212]
# [Epoch 7/200] [Train_Loss: 0.818399 / Valid_Loss: 0.803506]
# [Epoch 7/200] [Accuracy : 0.580263]
# [Epoch 8/200] [Train_Loss: 0.793604 / Valid_Loss: 0.772012]
# [Epoch 8/200] [Accuracy : 0.607375]
# [Epoch 9/200] [Train_Loss: 0.789128 / Valid_Loss: 0.751792]
# [Epoch 9/200] [Accuracy : 0.625950]
# [Epoch 10/200] [Train_Loss: 0.755184 / Valid_Loss: 0.730515]
# ...

# %%
# 모델 평가

def test_model(model, PATH):
    model = torch.load(PATH + 'model.pt')

    #---------------------- 모델 시험 ----------------------#
    model.eval()
    total    = 0.0
    accuracy = 0.0

    for batch_idx, data in enumerate(test_dataloader):
        x_test, y_test = data
        t_hat  = model(x_test)
        _, predicted = torch.max(t_hat.data, 1)
        total    += y_test.size(0)
        accuracy += (predicted == y_test).sum().item()

    accuracy = accuracy / total
    #-------------------------------------------------------#
    print(accuracy)

# %%
# 혼동 행렬

from sklearn.metrics import classification_report, confusion_matrix

def draw_confusion_matrix(model, xt, yt, PATH):
    y_pred = []
    y_true = []

    model.eval()
    y_hat  = model(xt)
    output = (torch.max(torch.exp(y_hat), 1)[1]).data.cpu().numpy()
    y_pred.extend(output)
    labels = yt.data.cpu().numpy()
    y_true.extend(labels)

    # 분류 항목
    classes = ('Normal', 'Type1', 'Type2','Type3')

    # Confusion Matrix 생성
    plt.figure(figsize=(7, 5))
    dlen  = float(len(xt))
    cm    = confusion_matrix(y_true, y_pred)
    df_cm = pd.DataFrame(cm / dlen,
                         index  =[i for i in classes],
                         columns=[i for i in classes])

    sns.heatmap(df_cm, annot=True, cmap=plt.cm.Blues)
    plt.title("Confusion Matrix", size=24, fontweight='bold')
    plt.xlabel("Predicted Label", size=16)
    plt.ylabel("Actual Label",   size=16)
    plt.rc('xtick', labelsize=12)
    plt.rc('ytick', labelsize=12)
    plt.yticks(rotation=0)
    plt.savefig(PATH + 'cm_output.png')

# %%
# 손실 그래프

def plot_loss_graph(loss_values, loss_values_v, PATH):
    plt.figure()
    plt.plot(loss_values)
    plt.plot(loss_values_v)
    plt.title("Training & Validation Loss")
    plt.ylabel("loss",  fontsize="large")
    plt.xlabel("epoch", fontsize="large")
    plt.legend(["train", "validation"])
    plt.tight_layout()
    plt.savefig(PATH + 'lossplot_output.png')

# %%
PATH ='save/DNN/'
test_model(DNN_model, PATH)
draw_confusion_matrix(DNN_model, x_test, y_test, PATH)
plot_loss_graph(DNN_loss_values, DNN_loss_values_v, PATH)
# Out:
# 0.7629

# %%
model = torch.load('save/DNN/model.pt')
model.eval()
