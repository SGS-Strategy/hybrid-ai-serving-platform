# %%
pip install numpy pandas scipy scikit-learn torch matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\kamp\lib\site-packages (1.21.6)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\kamp\lib\site-packages (1.3.5)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\envs\kamp\lib\site-packages (1.7.3)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\envs\kamp\lib\site-packages (1.0.2)
# Requirement already satisfied: torch in c:\users\user\anaconda3\envs\kamp\lib\site-packages (1.13.1)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\kamp\lib\site-packages (3.5.3)
# Requirement already satisfied: seaborn in c:\users\user\anaconda3\envs\kamp\lib\site-packages (0.12.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: typing-extensions in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from torch) (4.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\kamp\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.17.0)
# Could not fetch URL https://pypi.org/simple/pip/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/pip/ (Caused by SSLError("Can't connect to HTTPS URL because the SSL module is not available.")) - skipping
# WARNING: pip is configured with locations that require TLS/SSL, however the ssl module in Python is not available.
# WARNING: pip is configured with locations that require TLS/SSL, however the ssl module in Python is not available.
# WARNING: There was an error checking the latest version of pip.

# %%
import numpy as np
import pandas as pd
import random
import seaborn as sns
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
import os
os.chdir('C:/Users/user')
print(os.getcwd())          # 현재 위치
print(os.listdir())         # 현재 폴더 파일 목록
# Out:
# C:\Users\user
# ['.anaconda', '.aws', '.azure', '.cagent', '.conda', '.config', '.continuum', '.docker', '.eclipse', '.git', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.kube', '.local', '.matplotlib', '.ms-ad', '.p2', '.ssh', '.VirtualBox', '.vscode', '.vscode-shared', '3rd_project_1.ipynb', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'bentoml', 'codebuddy-project', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'eclipse-workspace', 'Favorites', 'hybrid-ai-serving-platform', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TM.blf', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{2ad838bc-efea-11ee-a54d-000d3a94eaa1}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'Recent', 'save', 'Saved Games', 'Searches', 'SendTo', 'sre_project', 'Templates', 'Untitled-1.ipynb', 'Videos', '시작 메뉴']

# %%
sensor1 = pd.read_csv('Downloads/private/g1_sensor1.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])
sensor2 = pd.read_csv('Downloads/private/g1_sensor2.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])
sensor3 = pd.read_csv('Downloads/private/g1_sensor3.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])
sensor4 = pd.read_csv('Downloads/private/g1_sensor4.csv', names=['time', 'normal', 'type1', 'type2', 'type3'])

# %%
sensor1
# Out:
#              time    normal     type1     type2     type3
# 0        0.000000 -0.853307 -3.464579  0.555219  3.919664
# 1        0.000736 -0.740463 -2.448986 -0.234687  4.145351
# 2        0.001472 -0.138630 -1.922383 -0.009000  2.941685
# 3        0.002208  0.049443 -0.906790 -0.272301  2.603155
# 4        0.002944 -0.289088 -0.568259 -0.986978  1.361874
# ...           ...       ...       ...       ...       ...
# 133148  97.996928 -0.518559 -1.878193  1.092805  1.069737
# 133149  97.997664 -1.045163 -1.502047  1.017576  1.144966
# 133150  97.998400 -0.894705 -1.765349  0.378129  1.370654
# 133151  97.999136 -0.518559 -0.937829  1.055191  1.709185
# 133152  97.999872 -1.045163 -0.749757  0.114827  1.822028
#
# [133153 rows x 5 columns]

# %%
# 4개의 센서로부터 140초간 수집한 데이터의 크기
# 열 값이 다른 이유는 각 센서의 샘플링 속도가 다르기 때문
print('sensor 1의 데이터 크기', sensor1.shape)
print('sensor 2의 데이터 크기', sensor2.shape)
print('sensor 3의 데이터 크기', sensor3.shape)
print('sensor 4의 데이터 크기', sensor4.shape)
# Out:
# sensor 1의 데이터 크기 (133153, 5)
# sensor 2의 데이터 크기 (128948, 5)
# sensor 3의 데이터 크기 (137255, 5)
# sensor 4의 데이터 크기 (128778, 5)

# %%
# 전처리 1 - 계측 시간의 동일화를 위한 데이터 선형보간
from scipy import interpolate

# 각 센서의 실제 시간 범위 확인
t_min = max(sensor1['time'].min(), sensor2['time'].min(), 
            sensor3['time'].min(), sensor4['time'].min())

x_new = np.arange(t_min, 98, 0.001)  # t_max → 98로 변경
y_new1 = []; y_new2 = []; y_new3 = []; y_new4 = []

for item in ['normal', 'type1', 'type2', 'type3']:
    f_linear1 = interpolate.interp1d(sensor1['time'], sensor1[item], kind='linear')
    y_new1.append(f_linear1(x_new))
    f_linear2 = interpolate.interp1d(sensor2['time'], sensor2[item], kind='linear')
    y_new2.append(f_linear2(x_new))
    f_linear3 = interpolate.interp1d(sensor3['time'], sensor3[item], kind='linear')
    y_new3.append(f_linear3(x_new))
    f_linear4 = interpolate.interp1d(sensor4['time'], sensor4[item], kind='linear')
    y_new4.append(f_linear4(x_new))

sensor1 = pd.DataFrame(np.array(y_new1).T, columns=['normal', 'type1', 'type2', 'type3'])
sensor2 = pd.DataFrame(np.array(y_new2).T, columns=['normal', 'type1', 'type2', 'type3'])
sensor3 = pd.DataFrame(np.array(y_new3).T, columns=['normal', 'type1', 'type2', 'type3'])
sensor4 = pd.DataFrame(np.array(y_new4).T, columns=['normal', 'type1', 'type2', 'type3'])

# %%
# 보간 결과 데이터 사이즈는 (140000, 4) 가 됨
sensor1
# Out:
#          normal     type1     type2     type3
# 0     -0.853307 -3.464579  0.555219  3.919664
# 1     -0.524588 -2.260096 -0.153734  3.713601
# 2     -0.003708 -1.193805 -0.197890  2.698827
# 3     -0.297674 -0.490986 -0.972668  1.338978
# 4     -0.091203  0.790771 -0.913384  0.701167
# ...         ...       ...       ...       ...
# 97995 -0.373416 -2.333656  1.299277 -0.373926
# 97996 -0.832559 -1.866745  0.966879  0.214415
# 97997 -0.570075 -1.841396  1.085446  1.077096
# 97998 -0.976476 -1.622250  0.725655  1.247997
# 97999 -0.588064 -1.090740  0.930082  1.646630
#
# [98000 rows x 4 columns]

# %%
print(len(x_new))
print(sensor1.shape)
# Out:
# 98000
# (98000, 4)

# %%
# 실제 취득된 형태로 데이터 재조정

normal_ = pd.concat([sensor1['normal'], sensor2['normal'], sensor3['normal'], sensor4['normal']], axis=1)
type1_  = pd.concat([sensor1['type1'],  sensor2['type1'],  sensor3['type1'],  sensor4['type1']],  axis=1)
type2_  = pd.concat([sensor1['type2'],  sensor2['type2'],  sensor3['type2'],  sensor4['type2']],  axis=1)
type3_  = pd.concat([sensor1['type3'],  sensor2['type3'],  sensor3['type3'],  sensor4['type3']],  axis=1)

normal_.columns = ['s1', 's2', 's3', 's4']
type1_.columns  = ['s1', 's2', 's3', 's4']
type2_.columns  = ['s1', 's2', 's3', 's4']
type3_.columns  = ['s1', 's2', 's3', 's4']

# %%
normal_
# Out:
#              s1        s2        s3        s4
# 0     -0.853307  0.048823 -0.437626 -1.116226
# 1     -0.524588 -0.029477 -0.149817 -0.659694
# 2     -0.003708 -0.004751  0.280889 -0.857345
# 3     -0.297674  0.009673 -0.303281 -0.685318
# 4     -0.091203  0.096215 -0.320263 -0.303108
# ...         ...       ...       ...       ...
# 97995 -0.373416 -0.888950 -0.443014  0.006653
# 97996 -0.832559 -0.513936 -0.245020  0.388302
# 97997 -0.570075 -0.423273  0.069456  0.440465
# 97998 -0.976476 -0.124498  0.046437  0.558750
# 97999 -0.588064  1.109751 -0.505657  0.986246
#
# [98000 rows x 4 columns]

# %%
# 데이터 시각화 (시간에 따른 계측값)
# class 1 : 정상상태 / class 2 : 비정상 상태
plt.figure(figsize=(10, 4))
plt.scatter(range(0, 300), normal_['s1'][:300], label="class = " + str(1), marker='o', s=5)
plt.scatter(range(0, 300), type1_['s1'][:300],  label="class = " + str(2), marker='o', s=5)
plt.legend(loc="lower right")
plt.xlabel("Sensor", fontsize=15)
plt.ylabel("Sensor Value", fontsize=15)
plt.show()
plt.close()

# %%
# 데이터의 센서별 상관관계
normal_.corr()
# Out:
#           s1        s2        s3        s4
# s1  1.000000 -0.005836  0.006875 -0.004118
# s2 -0.005836  1.000000  0.007688  0.090800
# s3  0.006875  0.007688  1.000000 -0.003134
# s4 -0.004118  0.090800 -0.003134  1.000000

# %%
# 데이터 상관관계 시각화
names = ['s1','s2','s3','s4']
cm = np.corrcoef(normal_[names].values.T)
sns.set(font_scale=0.8)
sns.heatmap(cm, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, 
yticklabels=names, xticklabels=names, cmap=plt.cm.Blues)
# Out:
# <AxesSubplot:>

# %%
# 전처리 2 - 데이터 필터링 (노이즈 제거)

M = 15

def moving_avg(series, M):
    result = np.convolve(series, np.ones(M), 'valid') / M
    return result.reshape(len(result), 1)

normal_s1 = moving_avg(normal_['s1'], M)
normal_s2 = moving_avg(normal_['s2'], M)
normal_s3 = moving_avg(normal_['s3'], M)
normal_s4 = moving_avg(normal_['s4'], M)

type1_s1 = moving_avg(type1_['s1'], M)
type1_s2 = moving_avg(type1_['s2'], M)
type1_s3 = moving_avg(type1_['s3'], M)
type1_s4 = moving_avg(type1_['s4'], M)

type2_s1 = moving_avg(type2_['s1'], M)
type2_s2 = moving_avg(type2_['s2'], M)
type2_s3 = moving_avg(type2_['s3'], M)
type2_s4 = moving_avg(type2_['s4'], M)

type3_s1 = moving_avg(type3_['s1'], M)
type3_s2 = moving_avg(type3_['s2'], M)
type3_s3 = moving_avg(type3_['s3'], M)
type3_s4 = moving_avg(type3_['s4'], M)

normal_temp = np.concatenate((normal_s1, normal_s2, normal_s3, normal_s4), axis=1)
type1_temp  = np.concatenate((type1_s1,  type1_s2,  type1_s3,  type1_s4),  axis=1)
type2_temp  = np.concatenate((type2_s1,  type2_s2,  type2_s3,  type2_s4),  axis=1)
type3_temp  = np.concatenate((type3_s1,  type3_s2,  type3_s3,  type3_s4),  axis=1)

# %%
# 전처리 3 - 데이터 정규화

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(normal_)

normal = scaler.transform(normal_temp)
type1  = scaler.transform(type1_temp)
type2  = scaler.transform(type2_temp)
type3  = scaler.transform(type3_temp)
# Out:
# C:\Users\user\anaconda3\envs\KAMP\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\user\anaconda3\envs\KAMP\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\user\anaconda3\envs\KAMP\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   "X does not have valid feature names, but"
# C:\Users\user\anaconda3\envs\KAMP\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   "X does not have valid feature names, but"

# %%
# 데이터가 (0,1)로 정규화됨

print(normal)
print('------------------------------------------------')
print('normal data size = ', normal.shape)
# Out:
# [[0.57598822 0.52068238 0.56439491 0.44633815]
#  [0.60960317 0.5202681  0.58169332 0.44931202]
#  [0.62990663 0.51985381 0.59547186 0.46346296]
#  ...
#  [0.57315523 0.43743837 0.57995884 0.50025121]
#  [0.53961982 0.41617889 0.57924143 0.51836582]
#  [0.51881022 0.42607817 0.57061104 0.53044597]]
# ------------------------------------------------
# normal data size =  (97986, 4)

# %%
print(normal_temp.shape)
# Out:
# (97986, 4)

# %%
# 데이터 사이즈 조정
# 97986개 중 앞뒤 잘라서 70000개 사용
normal = normal_temp[13000:83000][:]
type1  = type1_temp[13000:83000][:]
type2  = type2_temp[13000:83000][:]
type3  = type3_temp[13000:83000][:]

print(normal)
print('------------------------------------------------')
print('normal data size = ', normal.shape)
# Out:
# [[ 0.54951291  0.12675996  0.07188539  0.16646628]
#  [ 0.50786434  0.09200589  0.10676287  0.06563389]
#  [ 0.42099653  0.06494442  0.09471215 -0.00215144]
#  ...
#  [-0.58719062  0.15556896  0.06084194  0.0297946 ]
#  [-0.49091919  0.14499164  0.04614124 -0.06615765]
#  [-0.40298836  0.1613384   0.01713398 -0.17941622]]
# ------------------------------------------------
# normal data size =  (70000, 4)

# %%
# 데이터 분배 (학습/검증/테스트)
# 학습 : 검증 : 테스트 = 6 : 2 : 2
normal_train = normal[:42000];  normal_valid = normal[42000:56000];  normal_test = normal[56000:]
type1_train  = type1[:42000];   type1_valid  = type1[42000:56000];   type1_test  = type1[56000:]
type2_train  = type2[:42000];   type2_valid  = type2[42000:56000];   type2_test  = type2[56000:]
type3_train  = type3[:42000];   type3_valid  = type3[42000:56000];   type3_test  = type3[56000:]

train = np.concatenate((normal_train, type1_train, type2_train, type3_train))
valid = np.concatenate((normal_valid, type1_valid, type2_valid, type3_valid))
test  = np.concatenate((normal_test,  type1_test,  type2_test,  type3_test))

print("train data의 형태:", train.shape)
print("valid data의 형태:", valid.shape)
print(" test data의 형태:", test.shape)
# Out:
# train data의 형태: (168000, 4)
# valid data의 형태: (56000, 4)
#  test data의 형태: (56000, 4)

# %%
# 데이터 라벨링
# normal = 0 / type 1 = 1 / type 2 = 2 / type 3 = 3
train_label = np.concatenate((np.full((42000, 1), 0), np.full((42000, 1), 1), np.full((42000, 1), 2), np.full((42000, 1), 3)))
valid_label = np.concatenate((np.full((14000, 1), 0), np.full((14000, 1), 1), np.full((14000, 1), 2), np.full((14000, 1), 3)))
test_label  = np.concatenate((np.full((14000, 1), 0), np.full((14000, 1), 1), np.full((14000, 1), 2), np.full((14000, 1), 3)))

# %%
# 데이터 뒤섞기
# 순서에 의존하지 않고 임의의 데이터가 입력되는 것으로 간주하기 위함

idx = np.arange(train.shape[0])
np.random.shuffle(idx)
train       = train[idx]
train_label = train_label[idx]

idx_v = np.arange(valid.shape[0])
np.random.shuffle(idx_v)
valid       = valid[idx_v]
valid_label = valid_label[idx_v]

idx_t = np.arange(test.shape[0])
np.random.shuffle(idx_t)
test       = test[idx_t]
test_label = test_label[idx_t]

# %%
# 데이터 형태 변환 (array -> tensor 형태)

x_train = torch.from_numpy(train).float()
y_train = torch.from_numpy(train_label).float().T[0]

x_valid = torch.from_numpy(valid).float()
y_valid = torch.from_numpy(valid_label).float().T[0]

x_test = torch.from_numpy(test).float()
y_test = torch.from_numpy(test_label).float().T[0]

print("변경 전")
train

print("변경 후")
x_train
# Out:
# 변경 전
# 변경 후
# tensor([[ 0.4359, -0.3354,  0.0210, -0.1620],
#         [-0.6102,  0.3640, -0.0379, -0.3554],
#         [-1.6288, -1.2289, -0.0855, -0.2953],
#         ...,
#         [-1.5761, -0.0984,  0.1087,  0.3815],
#         [-1.4768,  1.4895,  0.1151,  0.2907],
#         [-0.5629, -0.4885, -0.0654,  0.5308]])

# %%
# 데이터 묶기

from torch.utils.data import TensorDataset, DataLoader

train          = TensorDataset(x_train, y_train)
train_dataloader = DataLoader(train, batch_size=5000, shuffle=True)

valid          = TensorDataset(x_valid, y_valid)
valid_dataloader = DataLoader(valid, batch_size=len(x_valid), shuffle=False)

test           = TensorDataset(x_test, y_test)
test_dataloader  = DataLoader(test,  batch_size=len(x_valid), shuffle=False)

# %%
# 심층신경망(DNN)
# 모델 내 은닉층을 많이 늘려서 학습의 결과를 향상시키는 방법

class KAMP_DNN(nn.Module):
    def __init__(self):
        super(KAMP_DNN, self).__init__()
        self.layer1  = nn.Linear(in_features=4,   out_features=100)
        self.layer2  = nn.Linear(in_features=100, out_features=100)
        self.layer3  = nn.Linear(in_features=100, out_features=100)
        self.layer4  = nn.Linear(in_features=100, out_features=4)
        self.dropout = nn.Dropout(0.2)
        self.relu    = nn.ReLU()

    def forward(self, input):
        out = self.layer1(input)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.layer2(out)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.layer3(out)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.layer4(out)
        return out

model_check = KAMP_DNN()
print(model_check)
# Out:
# KAMP_DNN(
#   (layer1): Linear(in_features=4, out_features=100, bias=True)
#   (layer2): Linear(in_features=100, out_features=100, bias=True)
#   (layer3): Linear(in_features=100, out_features=100, bias=True)
#   (layer4): Linear(in_features=100, out_features=4, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (relu): ReLU()
# )

# %%
# 모델 학습

def train_model(model, criterion, optimizer, num_epochs, train_dataloader, PATH):
    loss_values   = []
    loss_values_v = []
    check         = 0
    accuracy_past = 0

    for epoch in range(1, num_epochs + 1):

        #---------------------- 모델 학습 ----------------------#
        model.train()
        batch_number = 0
        running_loss = 0.0

        for batch_idx, samples in enumerate(train_dataloader):
            x_train, y_train = samples
            optimizer.zero_grad()
            y_hat = model.forward(x_train)
            loss  = criterion(y_hat, y_train.long())
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            batch_number += 1

        loss_values.append(running_loss / batch_number)

        #---------------------- 모델 검증 ----------------------#
        model.eval()
        accuracy = 0.0
        total    = 0.0

        for batch_idx, data in enumerate(valid_dataloader):
            x_valid, y_valid = data
            v_hat  = model.forward(x_valid)
            v_loss = criterion(v_hat, y_valid.long())
            _, predicted = torch.max(v_hat.data, 1)
            total    += y_valid.size(0)
            accuracy += (predicted == y_valid).sum().item()

        loss_values_v.append(v_loss.item())
        accuracy = accuracy / total

        #---------------- Check for early stopping --------------#
        if epoch % 1 == 0:
            print('[Epoch {}/{}] [Train_Loss: {:.6f} / Valid_Loss: {:.6f}]'.format(
                epoch, num_epochs, loss.item(), v_loss.item()))
            print('[Epoch {}/{}] [Accuracy : {:.6f}]'.format(
                epoch, num_epochs, accuracy))

        if accuracy_past > accuracy:
            check += 1
        else:
            check = 0
        accuracy_past = accuracy

        if check > 50:
            print('This is time to do early stopping')
            break

    torch.save(model, PATH + 'model.pt')
    return loss_values, loss_values_v

# %%
import os
os.makedirs('save/DNN/', exist_ok=True)

# %%
# %%time
# DNN 모델 학습

DNN_model  = KAMP_DNN()
num_epochs = 200
criterion  = nn.CrossEntropyLoss()
optimizer  = torch.optim.Adam(DNN_model.parameters())
PATH       = 'save/DNN/'

DNN_loss_values, DNN_loss_values_v = train_model(DNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)
# Out:
# [Epoch 1/200] [Train_Loss: 1.009898 / Valid_Loss: 0.976221]
# [Epoch 1/200] [Accuracy : 0.481429]
# [Epoch 2/200] [Train_Loss: 0.851237 / Valid_Loss: 0.843659]
# [Epoch 2/200] [Accuracy : 0.521821]
# [Epoch 3/200] [Train_Loss: 0.829639 / Valid_Loss: 0.798042]
# [Epoch 3/200] [Accuracy : 0.590214]
# [Epoch 4/200] [Train_Loss: 0.766155 / Valid_Loss: 0.743850]
# [Epoch 4/200] [Accuracy : 0.644536]
# [Epoch 5/200] [Train_Loss: 0.733040 / Valid_Loss: 0.715009]
# [Epoch 5/200] [Accuracy : 0.658875]
# [Epoch 6/200] [Train_Loss: 0.715042 / Valid_Loss: 0.695591]
# [Epoch 6/200] [Accuracy : 0.669482]
# [Epoch 7/200] [Train_Loss: 0.704010 / Valid_Loss: 0.679353]
# [Epoch 7/200] [Accuracy : 0.675000]
# [Epoch 8/200] [Train_Loss: 0.694801 / Valid_Loss: 0.661029]
# [Epoch 8/200] [Accuracy : 0.687946]
# [Epoch 9/200] [Train_Loss: 0.645439 / Valid_Loss: 0.647179]
# [Epoch 9/200] [Accuracy : 0.707179]
# [Epoch 10/200] [Train_Loss: 0.651866 / Valid_Loss: 0.633977]
# [Epoch 10/200] [Accuracy : 0.713893]
# [Epoch 11/200] [Train_Loss: 0.651625 / Valid_Loss: 0.623540]
# [Epoch 11/200] [Accuracy : 0.719089]
# [Epoch 12/200] [Train_Loss: 0.660015 / Valid_Loss: 0.614354]
# [Epoch 12/200] [Accuracy : 0.726875]
# [Epoch 13/200] [Train_Loss: 0.633601 / Valid_Loss: 0.609026]
# [Epoch 13/200] [Accuracy : 0.729911]
# [Epoch 14/200] [Train_Loss: 0.612596 / Valid_Loss: 0.604460]
# [Epoch 14/200] [Accuracy : 0.731893]
# [Epoch 15/200] [Train_Loss: 0.596367 / Valid_Loss: 0.603816]
# [Epoch 15/200] [Accuracy : 0.732268]
# [Epoch 16/200] [Train_Loss: 0.610955 / Valid_Loss: 0.598033]
# [Epoch 16/200] [Accuracy : 0.735625]
# [Epoch 17/200] [Train_Loss: 0.604571 / Valid_Loss: 0.596751]
# [Epoch 17/200] [Accuracy : 0.734964]
# [Epoch 18/200] [Train_Loss: 0.591244 / Valid_Loss: 0.592233]
# [Epoch 18/200] [Accuracy : 0.740089]
# [Epoch 19/200] [Train_Loss: 0.576036 / Valid_Loss: 0.589012]
# [Epoch 19/200] [Accuracy : 0.741732]
# [Epoch 20/200] [Train_Loss: 0.601717 / Valid_Loss: 0.586800]
# [Epoch 20/200] [Accuracy : 0.743411]
# [Epoch 21/200] [Train_Loss: 0.590189 / Valid_Loss: 0.584268]
# [Epoch 21/200] [Accuracy : 0.744946]
# [Epoch 22/200] [Train_Loss: 0.589182 / Valid_Loss: 0.585644]
# [Epoch 22/200] [Accuracy : 0.745321]
# [Epoch 23/200] [Train_Loss: 0.585927 / Valid_Loss: 0.583103]
# [Epoch 23/200] [Accuracy : 0.745446]
# [Epoch 24/200] [Train_Loss: 0.575290 / Valid_Loss: 0.581798]
# [Epoch 24/200] [Accuracy : 0.747643]
# [Epoch 25/200] [Train_Loss: 0.588682 / Valid_Loss: 0.581055]
# [Epoch 25/200] [Accuracy : 0.747893]
# [Epoch 26/200] [Train_Loss: 0.562757 / Valid_Loss: 0.576612]
# [Epoch 26/200] [Accuracy : 0.751000]
# [Epoch 27/200] [Train_Loss: 0.574867 / Valid_Loss: 0.578118]
# [Epoch 27/200] [Accuracy : 0.750554]
# [Epoch 28/200] [Train_Loss: 0.570691 / Valid_Loss: 0.577717]
# [Epoch 28/200] [Accuracy : 0.749179]
# [Epoch 29/200] [Train_Loss: 0.554303 / Valid_Loss: 0.577909]
# [Epoch 29/200] [Accuracy : 0.749429]
# [Epoch 30/200] [Train_Loss: 0.571413 / Valid_Loss: 0.576878]
# [Epoch 30/200] [Accuracy : 0.749179]
# [Epoch 31/200] [Train_Loss: 0.565079 / Valid_Loss: 0.576082]
# [Epoch 31/200] [Accuracy : 0.750518]
# [Epoch 32/200] [Train_Loss: 0.572543 / Valid_Loss: 0.576812]
# [Epoch 32/200] [Accuracy : 0.750696]
# [Epoch 33/200] [Train_Loss: 0.571783 / Valid_Loss: 0.573185]
# [Epoch 33/200] [Accuracy : 0.752250]
# [Epoch 34/200] [Train_Loss: 0.555528 / Valid_Loss: 0.572496]
# [Epoch 34/200] [Accuracy : 0.754232]
# [Epoch 35/200] [Train_Loss: 0.596473 / Valid_Loss: 0.576804]
# [Epoch 35/200] [Accuracy : 0.751375]
# [Epoch 36/200] [Train_Loss: 0.536434 / Valid_Loss: 0.570174]
# [Epoch 36/200] [Accuracy : 0.755446]
# [Epoch 37/200] [Train_Loss: 0.558732 / Valid_Loss: 0.571953]
# [Epoch 37/200] [Accuracy : 0.754161]
# [Epoch 38/200] [Train_Loss: 0.563632 / Valid_Loss: 0.570919]
# [Epoch 38/200] [Accuracy : 0.754625]
# [Epoch 39/200] [Train_Loss: 0.553523 / Valid_Loss: 0.572891]
# [Epoch 39/200] [Accuracy : 0.754054]
# [Epoch 40/200] [Train_Loss: 0.577630 / Valid_Loss: 0.575739]
# [Epoch 40/200] [Accuracy : 0.751393]
# [Epoch 41/200] [Train_Loss: 0.557062 / Valid_Loss: 0.571945]
# [Epoch 41/200] [Accuracy : 0.754179]
# [Epoch 42/200] [Train_Loss: 0.541158 / Valid_Loss: 0.572776]
# [Epoch 42/200] [Accuracy : 0.753893]
# [Epoch 43/200] [Train_Loss: 0.544060 / Valid_Loss: 0.570455]
# [Epoch 43/200] [Accuracy : 0.754696]
# [Epoch 44/200] [Train_Loss: 0.557944 / Valid_Loss: 0.574914]
# [Epoch 44/200] [Accuracy : 0.751839]
# [Epoch 45/200] [Train_Loss: 0.566280 / Valid_Loss: 0.571195]
# [Epoch 45/200] [Accuracy : 0.756089]
# [Epoch 46/200] [Train_Loss: 0.554721 / Valid_Loss: 0.570749]
# [Epoch 46/200] [Accuracy : 0.755304]
# [Epoch 47/200] [Train_Loss: 0.539886 / Valid_Loss: 0.571669]
# [Epoch 47/200] [Accuracy : 0.755018]
# [Epoch 48/200] [Train_Loss: 0.537916 / Valid_Loss: 0.572394]
# [Epoch 48/200] [Accuracy : 0.754857]
# [Epoch 49/200] [Train_Loss: 0.556953 / Valid_Loss: 0.570298]
# [Epoch 49/200] [Accuracy : 0.756875]
# [Epoch 50/200] [Train_Loss: 0.547274 / Valid_Loss: 0.570782]
# [Epoch 50/200] [Accuracy : 0.757000]
# [Epoch 51/200] [Train_Loss: 0.549083 / Valid_Loss: 0.570701]
# [Epoch 51/200] [Accuracy : 0.754696]
# [Epoch 52/200] [Train_Loss: 0.552278 / Valid_Loss: 0.567375]
# [Epoch 52/200] [Accuracy : 0.757321]
# [Epoch 53/200] [Train_Loss: 0.537947 / Valid_Loss: 0.570405]
# [Epoch 53/200] [Accuracy : 0.756732]
# [Epoch 54/200] [Train_Loss: 0.548529 / Valid_Loss: 0.567956]
# [Epoch 54/200] [Accuracy : 0.756536]
# [Epoch 55/200] [Train_Loss: 0.529787 / Valid_Loss: 0.571361]
# [Epoch 55/200] [Accuracy : 0.755589]
# [Epoch 56/200] [Train_Loss: 0.538625 / Valid_Loss: 0.569763]
# [Epoch 56/200] [Accuracy : 0.756125]
# [Epoch 57/200] [Train_Loss: 0.543087 / Valid_Loss: 0.569468]
# [Epoch 57/200] [Accuracy : 0.756946]
# [Epoch 58/200] [Train_Loss: 0.536590 / Valid_Loss: 0.567721]
# [Epoch 58/200] [Accuracy : 0.757482]
# [Epoch 59/200] [Train_Loss: 0.534336 / Valid_Loss: 0.573300]
# [Epoch 59/200] [Accuracy : 0.754482]
# [Epoch 60/200] [Train_Loss: 0.547758 / Valid_Loss: 0.569490]
# [Epoch 60/200] [Accuracy : 0.756714]
# [Epoch 61/200] [Train_Loss: 0.505412 / Valid_Loss: 0.569510]
# [Epoch 61/200] [Accuracy : 0.756946]
# [Epoch 62/200] [Train_Loss: 0.549091 / Valid_Loss: 0.569607]
# [Epoch 62/200] [Accuracy : 0.757071]
# [Epoch 63/200] [Train_Loss: 0.546268 / Valid_Loss: 0.567114]
# [Epoch 63/200] [Accuracy : 0.757411]
# [Epoch 64/200] [Train_Loss: 0.528759 / Valid_Loss: 0.569890]
# [Epoch 64/200] [Accuracy : 0.757125]
# [Epoch 65/200] [Train_Loss: 0.548184 / Valid_Loss: 0.566310]
# [Epoch 65/200] [Accuracy : 0.759679]
# [Epoch 66/200] [Train_Loss: 0.540476 / Valid_Loss: 0.565188]
# [Epoch 66/200] [Accuracy : 0.759500]
# [Epoch 67/200] [Train_Loss: 0.531999 / Valid_Loss: 0.567424]
# [Epoch 67/200] [Accuracy : 0.755732]
# [Epoch 68/200] [Train_Loss: 0.557070 / Valid_Loss: 0.566089]
# [Epoch 68/200] [Accuracy : 0.759929]
# [Epoch 69/200] [Train_Loss: 0.524200 / Valid_Loss: 0.565910]
# [Epoch 69/200] [Accuracy : 0.757875]
# [Epoch 70/200] [Train_Loss: 0.566086 / Valid_Loss: 0.568629]
# [Epoch 70/200] [Accuracy : 0.757875]
# [Epoch 71/200] [Train_Loss: 0.537089 / Valid_Loss: 0.566554]
# [Epoch 71/200] [Accuracy : 0.760536]
# [Epoch 72/200] [Train_Loss: 0.522897 / Valid_Loss: 0.567248]
# [Epoch 72/200] [Accuracy : 0.759393]
# [Epoch 73/200] [Train_Loss: 0.530885 / Valid_Loss: 0.571051]
# [Epoch 73/200] [Accuracy : 0.757482]
# [Epoch 74/200] [Train_Loss: 0.560978 / Valid_Loss: 0.566936]
# [Epoch 74/200] [Accuracy : 0.760536]
# [Epoch 75/200] [Train_Loss: 0.534181 / Valid_Loss: 0.567609]
# [Epoch 75/200] [Accuracy : 0.759214]
# [Epoch 76/200] [Train_Loss: 0.518008 / Valid_Loss: 0.568886]
# [Epoch 76/200] [Accuracy : 0.759321]
# [Epoch 77/200] [Train_Loss: 0.542739 / Valid_Loss: 0.569205]
# [Epoch 77/200] [Accuracy : 0.758000]
# [Epoch 78/200] [Train_Loss: 0.527455 / Valid_Loss: 0.569933]
# [Epoch 78/200] [Accuracy : 0.755214]
# [Epoch 79/200] [Train_Loss: 0.553901 / Valid_Loss: 0.566686]
# [Epoch 79/200] [Accuracy : 0.760179]
# [Epoch 80/200] [Train_Loss: 0.528866 / Valid_Loss: 0.566997]
# [Epoch 80/200] [Accuracy : 0.758018]
# [Epoch 81/200] [Train_Loss: 0.549101 / Valid_Loss: 0.565231]
# [Epoch 81/200] [Accuracy : 0.761321]
# [Epoch 82/200] [Train_Loss: 0.555520 / Valid_Loss: 0.568191]
# [Epoch 82/200] [Accuracy : 0.759714]
# [Epoch 83/200] [Train_Loss: 0.545912 / Valid_Loss: 0.566284]
# [Epoch 83/200] [Accuracy : 0.761179]
# [Epoch 84/200] [Train_Loss: 0.534807 / Valid_Loss: 0.565743]
# [Epoch 84/200] [Accuracy : 0.760839]
# [Epoch 85/200] [Train_Loss: 0.523098 / Valid_Loss: 0.568515]
# [Epoch 85/200] [Accuracy : 0.759250]
# [Epoch 86/200] [Train_Loss: 0.542299 / Valid_Loss: 0.567957]
# [Epoch 86/200] [Accuracy : 0.760018]
# [Epoch 87/200] [Train_Loss: 0.546279 / Valid_Loss: 0.566935]
# [Epoch 87/200] [Accuracy : 0.761018]
# [Epoch 88/200] [Train_Loss: 0.510844 / Valid_Loss: 0.568140]
# [Epoch 88/200] [Accuracy : 0.758661]
# [Epoch 89/200] [Train_Loss: 0.518900 / Valid_Loss: 0.567255]
# [Epoch 89/200] [Accuracy : 0.760232]
# [Epoch 90/200] [Train_Loss: 0.541668 / Valid_Loss: 0.564123]
# [Epoch 90/200] [Accuracy : 0.760018]
# [Epoch 91/200] [Train_Loss: 0.511250 / Valid_Loss: 0.566463]
# [Epoch 91/200] [Accuracy : 0.761321]
# [Epoch 92/200] [Train_Loss: 0.536960 / Valid_Loss: 0.564874]
# [Epoch 92/200] [Accuracy : 0.761482]
# [Epoch 93/200] [Train_Loss: 0.527934 / Valid_Loss: 0.565617]
# [Epoch 93/200] [Accuracy : 0.761661]
# [Epoch 94/200] [Train_Loss: 0.527375 / Valid_Loss: 0.566281]
# [Epoch 94/200] [Accuracy : 0.761143]
# [Epoch 95/200] [Train_Loss: 0.540111 / Valid_Loss: 0.566501]
# [Epoch 95/200] [Accuracy : 0.761000]
# [Epoch 96/200] [Train_Loss: 0.558554 / Valid_Loss: 0.570121]
# [Epoch 96/200] [Accuracy : 0.760125]
# [Epoch 97/200] [Train_Loss: 0.530633 / Valid_Loss: 0.562919]
# [Epoch 97/200] [Accuracy : 0.761732]
# [Epoch 98/200] [Train_Loss: 0.523276 / Valid_Loss: 0.568957]
# [Epoch 98/200] [Accuracy : 0.760679]
# [Epoch 99/200] [Train_Loss: 0.525622 / Valid_Loss: 0.565834]
# [Epoch 99/200] [Accuracy : 0.761196]
# [Epoch 100/200] [Train_Loss: 0.516492 / Valid_Loss: 0.565171]
# [Epoch 100/200] [Accuracy : 0.762232]
# [Epoch 101/200] [Train_Loss: 0.526240 / Valid_Loss: 0.565012]
# [Epoch 101/200] [Accuracy : 0.762393]
# [Epoch 102/200] [Train_Loss: 0.522771 / Valid_Loss: 0.564583]
# [Epoch 102/200] [Accuracy : 0.762482]
# [Epoch 103/200] [Train_Loss: 0.525954 / Valid_Loss: 0.566452]
# [Epoch 103/200] [Accuracy : 0.762411]
# [Epoch 104/200] [Train_Loss: 0.506026 / Valid_Loss: 0.564127]
# [Epoch 104/200] [Accuracy : 0.762607]
# [Epoch 105/200] [Train_Loss: 0.519033 / Valid_Loss: 0.569566]
# [Epoch 105/200] [Accuracy : 0.761000]
# [Epoch 106/200] [Train_Loss: 0.522816 / Valid_Loss: 0.568820]
# [Epoch 106/200] [Accuracy : 0.762375]
# [Epoch 107/200] [Train_Loss: 0.533315 / Valid_Loss: 0.565465]
# [Epoch 107/200] [Accuracy : 0.762929]
# [Epoch 108/200] [Train_Loss: 0.509361 / Valid_Loss: 0.563401]
# [Epoch 108/200] [Accuracy : 0.763500]
# [Epoch 109/200] [Train_Loss: 0.541470 / Valid_Loss: 0.562949]
# [Epoch 109/200] [Accuracy : 0.764018]
# [Epoch 110/200] [Train_Loss: 0.533217 / Valid_Loss: 0.561451]
# [Epoch 110/200] [Accuracy : 0.765054]
# [Epoch 111/200] [Train_Loss: 0.531350 / Valid_Loss: 0.569907]
# [Epoch 111/200] [Accuracy : 0.759804]
# [Epoch 112/200] [Train_Loss: 0.534841 / Valid_Loss: 0.566141]
# [Epoch 112/200] [Accuracy : 0.762071]
# [Epoch 113/200] [Train_Loss: 0.514234 / Valid_Loss: 0.569033]
# [Epoch 113/200] [Accuracy : 0.761696]
# [Epoch 114/200] [Train_Loss: 0.497231 / Valid_Loss: 0.565490]
# [Epoch 114/200] [Accuracy : 0.762161]
# [Epoch 115/200] [Train_Loss: 0.483217 / Valid_Loss: 0.564022]
# [Epoch 115/200] [Accuracy : 0.764304]
# [Epoch 116/200] [Train_Loss: 0.533353 / Valid_Loss: 0.566078]
# [Epoch 116/200] [Accuracy : 0.763518]
# [Epoch 117/200] [Train_Loss: 0.527096 / Valid_Loss: 0.570100]
# [Epoch 117/200] [Accuracy : 0.760446]
# [Epoch 118/200] [Train_Loss: 0.526837 / Valid_Loss: 0.566201]
# [Epoch 118/200] [Accuracy : 0.762446]
# [Epoch 119/200] [Train_Loss: 0.519149 / Valid_Loss: 0.568976]
# [Epoch 119/200] [Accuracy : 0.760411]
# [Epoch 120/200] [Train_Loss: 0.511156 / Valid_Loss: 0.568324]
# [Epoch 120/200] [Accuracy : 0.761446]
# [Epoch 121/200] [Train_Loss: 0.524156 / Valid_Loss: 0.563519]
# [Epoch 121/200] [Accuracy : 0.765089]
# [Epoch 122/200] [Train_Loss: 0.519015 / Valid_Loss: 0.566661]
# [Epoch 122/200] [Accuracy : 0.762107]
# [Epoch 123/200] [Train_Loss: 0.510093 / Valid_Loss: 0.568963]
# [Epoch 123/200] [Accuracy : 0.761786]
# [Epoch 124/200] [Train_Loss: 0.525477 / Valid_Loss: 0.566898]
# [Epoch 124/200] [Accuracy : 0.763375]
# [Epoch 125/200] [Train_Loss: 0.491315 / Valid_Loss: 0.570741]
# [Epoch 125/200] [Accuracy : 0.760875]
# [Epoch 126/200] [Train_Loss: 0.538592 / Valid_Loss: 0.568208]
# [Epoch 126/200] [Accuracy : 0.762357]
# [Epoch 127/200] [Train_Loss: 0.514866 / Valid_Loss: 0.568110]
# [Epoch 127/200] [Accuracy : 0.762750]
# [Epoch 128/200] [Train_Loss: 0.512195 / Valid_Loss: 0.563352]
# [Epoch 128/200] [Accuracy : 0.764893]
# [Epoch 129/200] [Train_Loss: 0.515048 / Valid_Loss: 0.564360]
# [Epoch 129/200] [Accuracy : 0.762179]
# [Epoch 130/200] [Train_Loss: 0.517645 / Valid_Loss: 0.567201]
# [Epoch 130/200] [Accuracy : 0.763429]
# [Epoch 131/200] [Train_Loss: 0.530520 / Valid_Loss: 0.564449]
# [Epoch 131/200] [Accuracy : 0.763357]
# [Epoch 132/200] [Train_Loss: 0.497513 / Valid_Loss: 0.565878]
# [Epoch 132/200] [Accuracy : 0.763607]
# [Epoch 133/200] [Train_Loss: 0.517096 / Valid_Loss: 0.566832]
# [Epoch 133/200] [Accuracy : 0.763804]
# [Epoch 134/200] [Train_Loss: 0.494987 / Valid_Loss: 0.567356]
# [Epoch 134/200] [Accuracy : 0.762161]
# [Epoch 135/200] [Train_Loss: 0.510469 / Valid_Loss: 0.570466]
# [Epoch 135/200] [Accuracy : 0.761482]
# [Epoch 136/200] [Train_Loss: 0.520243 / Valid_Loss: 0.566431]
# [Epoch 136/200] [Accuracy : 0.763732]
# [Epoch 137/200] [Train_Loss: 0.550541 / Valid_Loss: 0.566049]
# [Epoch 137/200] [Accuracy : 0.764018]
# [Epoch 138/200] [Train_Loss: 0.512250 / Valid_Loss: 0.567863]
# [Epoch 138/200] [Accuracy : 0.762911]
# [Epoch 139/200] [Train_Loss: 0.523277 / Valid_Loss: 0.567938]
# [Epoch 139/200] [Accuracy : 0.762464]
# [Epoch 140/200] [Train_Loss: 0.508596 / Valid_Loss: 0.564502]
# [Epoch 140/200] [Accuracy : 0.764018]
# [Epoch 141/200] [Train_Loss: 0.530015 / Valid_Loss: 0.566744]
# [Epoch 141/200] [Accuracy : 0.763821]
# [Epoch 142/200] [Train_Loss: 0.526290 / Valid_Loss: 0.573686]
# [Epoch 142/200] [Accuracy : 0.760411]
# [Epoch 143/200] [Train_Loss: 0.494101 / Valid_Loss: 0.564746]
# [Epoch 143/200] [Accuracy : 0.763625]
# [Epoch 144/200] [Train_Loss: 0.515345 / Valid_Loss: 0.566729]
# [Epoch 144/200] [Accuracy : 0.765000]
# [Epoch 145/200] [Train_Loss: 0.499689 / Valid_Loss: 0.567719]
# [Epoch 145/200] [Accuracy : 0.763393]
# [Epoch 146/200] [Train_Loss: 0.517987 / Valid_Loss: 0.564971]
# [Epoch 146/200] [Accuracy : 0.765304]
# [Epoch 147/200] [Train_Loss: 0.510885 / Valid_Loss: 0.566465]
# [Epoch 147/200] [Accuracy : 0.764982]
# [Epoch 148/200] [Train_Loss: 0.529397 / Valid_Loss: 0.563414]
# [Epoch 148/200] [Accuracy : 0.764750]
# [Epoch 149/200] [Train_Loss: 0.514036 / Valid_Loss: 0.567375]
# [Epoch 149/200] [Accuracy : 0.763875]
# [Epoch 150/200] [Train_Loss: 0.516742 / Valid_Loss: 0.569122]
# [Epoch 150/200] [Accuracy : 0.761518]
# [Epoch 151/200] [Train_Loss: 0.527123 / Valid_Loss: 0.567714]
# [Epoch 151/200] [Accuracy : 0.764286]
# [Epoch 152/200] [Train_Loss: 0.481116 / Valid_Loss: 0.565805]
# [Epoch 152/200] [Accuracy : 0.764607]
# [Epoch 153/200] [Train_Loss: 0.510634 / Valid_Loss: 0.568848]
# [Epoch 153/200] [Accuracy : 0.764054]
# [Epoch 154/200] [Train_Loss: 0.526645 / Valid_Loss: 0.569173]
# [Epoch 154/200] [Accuracy : 0.763411]
# [Epoch 155/200] [Train_Loss: 0.498191 / Valid_Loss: 0.565757]
# [Epoch 155/200] [Accuracy : 0.764411]
# [Epoch 156/200] [Train_Loss: 0.554783 / Valid_Loss: 0.564998]
# [Epoch 156/200] [Accuracy : 0.764268]
# [Epoch 157/200] [Train_Loss: 0.537089 / Valid_Loss: 0.566973]
# [Epoch 157/200] [Accuracy : 0.763250]
# [Epoch 158/200] [Train_Loss: 0.521308 / Valid_Loss: 0.564366]
# [Epoch 158/200] [Accuracy : 0.764161]
# [Epoch 159/200] [Train_Loss: 0.502403 / Valid_Loss: 0.569156]
# [Epoch 159/200] [Accuracy : 0.764161]
# [Epoch 160/200] [Train_Loss: 0.529458 / Valid_Loss: 0.564385]
# [Epoch 160/200] [Accuracy : 0.765589]
# [Epoch 161/200] [Train_Loss: 0.494954 / Valid_Loss: 0.565343]
# [Epoch 161/200] [Accuracy : 0.765786]
# [Epoch 162/200] [Train_Loss: 0.522308 / Valid_Loss: 0.565615]
# [Epoch 162/200] [Accuracy : 0.765161]
# [Epoch 163/200] [Train_Loss: 0.536877 / Valid_Loss: 0.566490]
# [Epoch 163/200] [Accuracy : 0.765482]
# [Epoch 164/200] [Train_Loss: 0.496400 / Valid_Loss: 0.567880]
# [Epoch 164/200] [Accuracy : 0.764214]
# [Epoch 165/200] [Train_Loss: 0.510650 / Valid_Loss: 0.567153]
# [Epoch 165/200] [Accuracy : 0.764375]
# [Epoch 166/200] [Train_Loss: 0.506673 / Valid_Loss: 0.567226]
# [Epoch 166/200] [Accuracy : 0.763893]
# [Epoch 167/200] [Train_Loss: 0.525431 / Valid_Loss: 0.570722]
# [Epoch 167/200] [Accuracy : 0.764393]
# [Epoch 168/200] [Train_Loss: 0.524599 / Valid_Loss: 0.567009]
# [Epoch 168/200] [Accuracy : 0.763732]
# [Epoch 169/200] [Train_Loss: 0.492421 / Valid_Loss: 0.566507]
# [Epoch 169/200] [Accuracy : 0.765089]
# [Epoch 170/200] [Train_Loss: 0.526079 / Valid_Loss: 0.565561]
# [Epoch 170/200] [Accuracy : 0.764000]
# [Epoch 171/200] [Train_Loss: 0.548095 / Valid_Loss: 0.562546]
# [Epoch 171/200] [Accuracy : 0.767714]
# [Epoch 172/200] [Train_Loss: 0.512009 / Valid_Loss: 0.568940]
# [Epoch 172/200] [Accuracy : 0.765286]
# [Epoch 173/200] [Train_Loss: 0.528842 / Valid_Loss: 0.567351]
# [Epoch 173/200] [Accuracy : 0.765607]
# [Epoch 174/200] [Train_Loss: 0.491541 / Valid_Loss: 0.568668]
# [Epoch 174/200] [Accuracy : 0.763875]
# [Epoch 175/200] [Train_Loss: 0.525121 / Valid_Loss: 0.568714]
# [Epoch 175/200] [Accuracy : 0.764821]
# [Epoch 176/200] [Train_Loss: 0.512773 / Valid_Loss: 0.564094]
# [Epoch 176/200] [Accuracy : 0.766054]
# [Epoch 177/200] [Train_Loss: 0.528079 / Valid_Loss: 0.565962]
# [Epoch 177/200] [Accuracy : 0.764500]
# [Epoch 178/200] [Train_Loss: 0.519133 / Valid_Loss: 0.569695]
# [Epoch 178/200] [Accuracy : 0.763054]
# [Epoch 179/200] [Train_Loss: 0.497722 / Valid_Loss: 0.565039]
# [Epoch 179/200] [Accuracy : 0.764429]
# [Epoch 180/200] [Train_Loss: 0.522698 / Valid_Loss: 0.567499]
# [Epoch 180/200] [Accuracy : 0.763964]
# [Epoch 181/200] [Train_Loss: 0.525183 / Valid_Loss: 0.569392]
# [Epoch 181/200] [Accuracy : 0.762554]
# [Epoch 182/200] [Train_Loss: 0.522850 / Valid_Loss: 0.564111]
# [Epoch 182/200] [Accuracy : 0.766268]
# [Epoch 183/200] [Train_Loss: 0.514957 / Valid_Loss: 0.566697]
# [Epoch 183/200] [Accuracy : 0.764679]
# [Epoch 184/200] [Train_Loss: 0.511494 / Valid_Loss: 0.564909]
# [Epoch 184/200] [Accuracy : 0.766125]
# [Epoch 185/200] [Train_Loss: 0.500814 / Valid_Loss: 0.563765]
# [Epoch 185/200] [Accuracy : 0.765732]
# [Epoch 186/200] [Train_Loss: 0.508158 / Valid_Loss: 0.565282]
# [Epoch 186/200] [Accuracy : 0.765036]
# [Epoch 187/200] [Train_Loss: 0.519326 / Valid_Loss: 0.566749]
# [Epoch 187/200] [Accuracy : 0.766036]
# [Epoch 188/200] [Train_Loss: 0.520214 / Valid_Loss: 0.563306]
# [Epoch 188/200] [Accuracy : 0.766893]
# [Epoch 189/200] [Train_Loss: 0.516898 / Valid_Loss: 0.564761]
# [Epoch 189/200] [Accuracy : 0.766036]
# [Epoch 190/200] [Train_Loss: 0.488178 / Valid_Loss: 0.565592]
# [Epoch 190/200] [Accuracy : 0.764982]
# [Epoch 191/200] [Train_Loss: 0.495604 / Valid_Loss: 0.565551]
# [Epoch 191/200] [Accuracy : 0.766786]
# [Epoch 192/200] [Train_Loss: 0.514655 / Valid_Loss: 0.567565]
# [Epoch 192/200] [Accuracy : 0.764446]
# [Epoch 193/200] [Train_Loss: 0.499005 / Valid_Loss: 0.568449]
# [Epoch 193/200] [Accuracy : 0.763607]
# [Epoch 194/200] [Train_Loss: 0.537417 / Valid_Loss: 0.570565]
# [Epoch 194/200] [Accuracy : 0.763339]
# [Epoch 195/200] [Train_Loss: 0.516690 / Valid_Loss: 0.568428]
# [Epoch 195/200] [Accuracy : 0.763661]
# [Epoch 196/200] [Train_Loss: 0.489455 / Valid_Loss: 0.566817]
# [Epoch 196/200] [Accuracy : 0.766036]
# [Epoch 197/200] [Train_Loss: 0.525778 / Valid_Loss: 0.566284]
# [Epoch 197/200] [Accuracy : 0.763786]
# [Epoch 198/200] [Train_Loss: 0.513485 / Valid_Loss: 0.565592]
# [Epoch 198/200] [Accuracy : 0.765018]
# [Epoch 199/200] [Train_Loss: 0.514037 / Valid_Loss: 0.567130]
# [Epoch 199/200] [Accuracy : 0.765339]
# [Epoch 200/200] [Train_Loss: 0.524276 / Valid_Loss: 0.565974]
# [Epoch 200/200] [Accuracy : 0.766875]
# Wall time: 22min 38s
# [Epoch 85/200] [Train_Loss: 0.546301 / Valid_Loss: 0.597392]
# [Epoch 85/200] [Accuracy : 0.731400]
# [Epoch 86/200] [Train_Loss: 0.551254 / Valid_Loss: 0.588654]
# [Epoch 86/200] [Accuracy : 0.739175]
# [Epoch 87/200] [Train_Loss: 0.551569 / Valid_Loss: 0.603571]
# [Epoch 87/200] [Accuracy : 0.731400]
# [Epoch 88/200] [Train_Loss: 0.537977 / Valid_Loss: 0.592114]
# [Epoch 88/200] [Accuracy : 0.735587]
# [Epoch 89/200] [Train_Loss: 0.571129 / Valid_Loss: 0.589945]
# [Epoch 89/200] [Accuracy : 0.737900]
# [Epoch 90/200] [Train_Loss: 0.573152 / Valid_Loss: 0.593364]
# [Epoch 90/200] [Accuracy : 0.738400]
# [Epoch 91/200] [Train_Loss: 0.547854 / Valid_Loss: 0.589860]
# [Epoch 91/200] [Accuracy : 0.736513]
# [Epoch 92/200] [Train_Loss: 0.551103 / Valid_Loss: 0.594680]
# [Epoch 92/200] [Accuracy : 0.734912]
# [Epoch 93/200] [Train_Loss: 0.561888 / Valid_Loss: 0.592375]
# [Epoch 93/200] [Accuracy : 0.736587]
# [Epoch 94/200] [Train_Loss: 0.547607 / Valid_Loss: 0.590397]
# [Epoch 94/200] [Accuracy : 0.736788]
# [Epoch 95/200] [Train_Loss: 0.555234 / Valid_Loss: 0.585879]
# [Epoch 95/200] [Accuracy : 0.740550]
# [Epoch 96/200] [Train_Loss: 0.550785 / Valid_Loss: 0.588081]
# [Epoch 96/200] [Accuracy : 0.740337]
# [Epoch 97/200] [Train_Loss: 0.551222 / Valid_Loss: 0.592146]
# [Epoch 97/200] [Accuracy : 0.735975]
# [Epoch 98/200] [Train_Loss: 0.555683 / Valid_Loss: 0.588539]
# [Epoch 98/200] [Accuracy : 0.741862]
# [Epoch 99/200] [Train_Loss: 0.547226 / Valid_Loss: 0.592212]
# [Epoch 99/200] [Accuracy : 0.739275]
# [Epoch 100/200] [Train_Loss: 0.567480 / Valid_Loss: 0.590120]
# [Epoch 100/200] [Accuracy : 0.734237]
# [Epoch 101/200] [Train_Loss: 0.559870 / Valid_Loss: 0.589952]
# [Epoch 101/200] [Accuracy : 0.738988]
# [Epoch 102/200] [Train_Loss: 0.570937 / Valid_Loss: 0.589634]
# [Epoch 102/200] [Accuracy : 0.737812]
# [Epoch 103/200] [Train_Loss: 0.549561 / Valid_Loss: 0.591082]
# [Epoch 103/200] [Accuracy : 0.737825]
# [Epoch 104/200] [Train_Loss: 0.559790 / Valid_Loss: 0.594135]
# [Epoch 104/200] [Accuracy : 0.732925]
# [Epoch 105/200] [Train_Loss: 0.549996 / Valid_Loss: 0.591389]
# [Epoch 105/200] [Accuracy : 0.734062]
# [Epoch 106/200] [Train_Loss: 0.573510 / Valid_Loss: 0.594587]
# [Epoch 106/200] [Accuracy : 0.735975]
# [Epoch 107/200] [Train_Loss: 0.562305 / Valid_Loss: 0.587219]
# [Epoch 107/200] [Accuracy : 0.742188]
# [Epoch 108/200] [Train_Loss: 0.552971 / Valid_Loss: 0.591899]
# [Epoch 108/200] [Accuracy : 0.736775]
# [Epoch 109/200] [Train_Loss: 0.547666 / Valid_Loss: 0.586690]
# [Epoch 109/200] [Accuracy : 0.739575]
# [Epoch 110/200] [Train_Loss: 0.562763 / Valid_Loss: 0.592411]
# [Epoch 110/200] [Accuracy : 0.736425]
# [Epoch 111/200] [Train_Loss: 0.553396 / Valid_Loss: 0.593567]
# [Epoch 111/200] [Accuracy : 0.734613]
# [Epoch 112/200] [Train_Loss: 0.565104 / Valid_Loss: 0.593293]
# [Epoch 112/200] [Accuracy : 0.736988]
# [Epoch 113/200] [Train_Loss: 0.555831 / Valid_Loss: 0.590202]
# [Epoch 113/200] [Accuracy : 0.737675]
# [Epoch 114/200] [Train_Loss: 0.543188 / Valid_Loss: 0.587679]
# [Epoch 114/200] [Accuracy : 0.739938]
# [Epoch 115/200] [Train_Loss: 0.529391 / Valid_Loss: 0.589394]
# [Epoch 115/200] [Accuracy : 0.737812]
# [Epoch 116/200] [Train_Loss: 0.559574 / Valid_Loss: 0.593700]
# [Epoch 116/200] [Accuracy : 0.735625]
# [Epoch 117/200] [Train_Loss: 0.554749 / Valid_Loss: 0.595678]
# [Epoch 117/200] [Accuracy : 0.734363]
# [Epoch 118/200] [Train_Loss: 0.555625 / Valid_Loss: 0.592359]
# [Epoch 118/200] [Accuracy : 0.733862]
# [Epoch 119/200] [Train_Loss: 0.541637 / Valid_Loss: 0.595858]
# [Epoch 119/200] [Accuracy : 0.735888]
# [Epoch 120/200] [Train_Loss: 0.557063 / Valid_Loss: 0.591306]
# [Epoch 120/200] [Accuracy : 0.737325]
# [Epoch 121/200] [Train_Loss: 0.546806 / Valid_Loss: 0.590832]
# [Epoch 121/200] [Accuracy : 0.737625]
# [Epoch 122/200] [Train_Loss: 0.543414 / Valid_Loss: 0.588879]
# [Epoch 122/200] [Accuracy : 0.740100]
# [Epoch 123/200] [Train_Loss: 0.567516 / Valid_Loss: 0.590417]
# [Epoch 123/200] [Accuracy : 0.737375]
# [Epoch 124/200] [Train_Loss: 0.530855 / Valid_Loss: 0.590878]
# [Epoch 124/200] [Accuracy : 0.735387]
# [Epoch 125/200] [Train_Loss: 0.540380 / Valid_Loss: 0.590506]
# [Epoch 125/200] [Accuracy : 0.739038]
# [Epoch 126/200] [Train_Loss: 0.524920 / Valid_Loss: 0.591673]
# [Epoch 126/200] [Accuracy : 0.736662]
# [Epoch 127/200] [Train_Loss: 0.554423 / Valid_Loss: 0.594145]
# [Epoch 127/200] [Accuracy : 0.734675]
# [Epoch 128/200] [Train_Loss: 0.555460 / Valid_Loss: 0.592652]
# [Epoch 128/200] [Accuracy : 0.737050]
# [Epoch 129/200] [Train_Loss: 0.543773 / Valid_Loss: 0.586230]
# [Epoch 129/200] [Accuracy : 0.739575]
# [Epoch 130/200] [Train_Loss: 0.533135 / Valid_Loss: 0.596777]
# [Epoch 130/200] [Accuracy : 0.733888]
# [Epoch 131/200] [Train_Loss: 0.543264 / Valid_Loss: 0.589453]
# [Epoch 131/200] [Accuracy : 0.738263]
# [Epoch 132/200] [Train_Loss: 0.546667 / Valid_Loss: 0.591755]
# [Epoch 132/200] [Accuracy : 0.737875]
# [Epoch 133/200] [Train_Loss: 0.552981 / Valid_Loss: 0.591717]
# [Epoch 133/200] [Accuracy : 0.734563]
# [Epoch 134/200] [Train_Loss: 0.556765 / Valid_Loss: 0.590478]
# [Epoch 134/200] [Accuracy : 0.740925]
# [Epoch 135/200] [Train_Loss: 0.543050 / Valid_Loss: 0.594519]
# [Epoch 135/200] [Accuracy : 0.734525]
# [Epoch 136/200] [Train_Loss: 0.534158 / Valid_Loss: 0.589505]
# [Epoch 136/200] [Accuracy : 0.738838]
# [Epoch 137/200] [Train_Loss: 0.554121 / Valid_Loss: 0.590367]
# [Epoch 137/200] [Accuracy : 0.737287]
# [Epoch 138/200] [Train_Loss: 0.537101 / Valid_Loss: 0.592340]
# [Epoch 138/200] [Accuracy : 0.735625]
# [Epoch 139/200] [Train_Loss: 0.542068 / Valid_Loss: 0.589866]
# [Epoch 139/200] [Accuracy : 0.737625]
# [Epoch 140/200] [Train_Loss: 0.540352 / Valid_Loss: 0.586841]
# [Epoch 140/200] [Accuracy : 0.740012]
# [Epoch 141/200] [Train_Loss: 0.555030 / Valid_Loss: 0.589961]
# [Epoch 141/200] [Accuracy : 0.737812]
# [Epoch 142/200] [Train_Loss: 0.551748 / Valid_Loss: 0.588998]
# [Epoch 142/200] [Accuracy : 0.739700]
# [Epoch 143/200] [Train_Loss: 0.560903 / Valid_Loss: 0.588877]
# [Epoch 143/200] [Accuracy : 0.739563]
# [Epoch 144/200] [Train_Loss: 0.557485 / Valid_Loss: 0.598561]
# [Epoch 144/200] [Accuracy : 0.730625]
# [Epoch 145/200] [Train_Loss: 0.554175 / Valid_Loss: 0.591904]
# [Epoch 145/200] [Accuracy : 0.733862]
# [Epoch 146/200] [Train_Loss: 0.555026 / Valid_Loss: 0.594293]
# [Epoch 146/200] [Accuracy : 0.731912]
# [Epoch 147/200] [Train_Loss: 0.538134 / Valid_Loss: 0.588914]
# [Epoch 147/200] [Accuracy : 0.740550]
# [Epoch 148/200] [Train_Loss: 0.536274 / Valid_Loss: 0.588102]
# [Epoch 148/200] [Accuracy : 0.740925]
# [Epoch 149/200] [Train_Loss: 0.542727 / Valid_Loss: 0.587466]
# [Epoch 149/200] [Accuracy : 0.738263]
# [Epoch 150/200] [Train_Loss: 0.518033 / Valid_Loss: 0.590841]
# [Epoch 150/200] [Accuracy : 0.736575]
# [Epoch 151/200] [Train_Loss: 0.543277 / Valid_Loss: 0.591605]
# [Epoch 151/200] [Accuracy : 0.736850]
# [Epoch 152/200] [Train_Loss: 0.548319 / Valid_Loss: 0.586787]
# [Epoch 152/200] [Accuracy : 0.741413]
# [Epoch 153/200] [Train_Loss: 0.546340 / Valid_Loss: 0.588823]
# [Epoch 153/200] [Accuracy : 0.739425]
# [Epoch 154/200] [Train_Loss: 0.540820 / Valid_Loss: 0.592068]
# [Epoch 154/200] [Accuracy : 0.735975]
# [Epoch 155/200] [Train_Loss: 0.561028 / Valid_Loss: 0.593757]
# [Epoch 155/200] [Accuracy : 0.735513]
# [Epoch 156/200] [Train_Loss: 0.552665 / Valid_Loss: 0.592439]
# [Epoch 156/200] [Accuracy : 0.735975]
# [Epoch 157/200] [Train_Loss: 0.541045 / Valid_Loss: 0.582437]
# [Epoch 157/200] [Accuracy : 0.742975]
# [Epoch 158/200] [Train_Loss: 0.546556 / Valid_Loss: 0.590130]
# [Epoch 158/200] [Accuracy : 0.735150]
# [Epoch 159/200] [Train_Loss: 0.553509 / Valid_Loss: 0.595711]
# [Epoch 159/200] [Accuracy : 0.735463]
# [Epoch 160/200] [Train_Loss: 0.532825 / Valid_Loss: 0.588990]
# [Epoch 160/200] [Accuracy : 0.738487]
# [Epoch 161/200] [Train_Loss: 0.541732 / Valid_Loss: 0.585562]
# [Epoch 161/200] [Accuracy : 0.741900]
# [Epoch 162/200] [Train_Loss: 0.536121 / Valid_Loss: 0.592795]
# [Epoch 162/200] [Accuracy : 0.737888]
# [Epoch 163/200] [Train_Loss: 0.554341 / Valid_Loss: 0.589246]
# [Epoch 163/200] [Accuracy : 0.736825]
# [Epoch 164/200] [Train_Loss: 0.529789 / Valid_Loss: 0.587155]
# [Epoch 164/200] [Accuracy : 0.741850]
# [Epoch 165/200] [Train_Loss: 0.545315 / Valid_Loss: 0.588034]
# [Epoch 165/200] [Accuracy : 0.739200]
# [Epoch 166/200] [Train_Loss: 0.540387 / Valid_Loss: 0.597025]
# [Epoch 166/200] [Accuracy : 0.737650]
# [Epoch 167/200] [Train_Loss: 0.558290 / Valid_Loss: 0.588090]
# [Epoch 167/200] [Accuracy : 0.740463]
# [Epoch 168/200] [Train_Loss: 0.542691 / Valid_Loss: 0.584813]
# [Epoch 168/200] [Accuracy : 0.740237]
# [Epoch 169/200] [Train_Loss: 0.541147 / Valid_Loss: 0.591654]
# [Epoch 169/200] [Accuracy : 0.733888]
# [Epoch 170/200] [Train_Loss: 0.550714 / Valid_Loss: 0.583856]
# [Epoch 170/200] [Accuracy : 0.741850]
# [Epoch 171/200] [Train_Loss: 0.545145 / Valid_Loss: 0.590736]
# [Epoch 171/200] [Accuracy : 0.738637]
# [Epoch 172/200] [Train_Loss: 0.541568 / Valid_Loss: 0.594724]
# [Epoch 172/200] [Accuracy : 0.735313]
# [Epoch 173/200] [Train_Loss: 0.532976 / Valid_Loss: 0.590540]
# [Epoch 173/200] [Accuracy : 0.739850]
# [Epoch 174/200] [Train_Loss: 0.548030 / Valid_Loss: 0.589492]
# [Epoch 174/200] [Accuracy : 0.739400]
# [Epoch 175/200] [Train_Loss: 0.545264 / Valid_Loss: 0.586237]
# [Epoch 175/200] [Accuracy : 0.742800]
# [Epoch 176/200] [Train_Loss: 0.548979 / Valid_Loss: 0.594361]
# [Epoch 176/200] [Accuracy : 0.731213]
# [Epoch 177/200] [Train_Loss: 0.552538 / Valid_Loss: 0.587561]
# [Epoch 177/200] [Accuracy : 0.738487]
# [Epoch 178/200] [Train_Loss: 0.545801 / Valid_Loss: 0.587669]
# [Epoch 178/200] [Accuracy : 0.738213]
# [Epoch 179/200] [Train_Loss: 0.537137 / Valid_Loss: 0.595108]
# [Epoch 179/200] [Accuracy : 0.735938]
# [Epoch 180/200] [Train_Loss: 0.530573 / Valid_Loss: 0.588642]
# [Epoch 180/200] [Accuracy : 0.742088]
# [Epoch 181/200] [Train_Loss: 0.528581 / Valid_Loss: 0.586429]
# [Epoch 181/200] [Accuracy : 0.741413]
# [Epoch 182/200] [Train_Loss: 0.551174 / Valid_Loss: 0.590583]
# [Epoch 182/200] [Accuracy : 0.739025]
# [Epoch 183/200] [Train_Loss: 0.546774 / Valid_Loss: 0.591363]
# [Epoch 183/200] [Accuracy : 0.736725]
# [Epoch 184/200] [Train_Loss: 0.534960 / Valid_Loss: 0.591519]
# [Epoch 184/200] [Accuracy : 0.738688]
# [Epoch 185/200] [Train_Loss: 0.545087 / Valid_Loss: 0.585579]
# [Epoch 185/200] [Accuracy : 0.738000]
# [Epoch 186/200] [Train_Loss: 0.530293 / Valid_Loss: 0.592064]
# [Epoch 186/200] [Accuracy : 0.738575]
# [Epoch 187/200] [Train_Loss: 0.526591 / Valid_Loss: 0.590464]
# [Epoch 187/200] [Accuracy : 0.739637]
# [Epoch 188/200] [Train_Loss: 0.535589 / Valid_Loss: 0.591068]
# [Epoch 188/200] [Accuracy : 0.737163]
# [Epoch 189/200] [Train_Loss: 0.533146 / Valid_Loss: 0.588885]
# [Epoch 189/200] [Accuracy : 0.741038]
# [Epoch 190/200] [Train_Loss: 0.540900 / Valid_Loss: 0.597225]
# [Epoch 190/200] [Accuracy : 0.731862]
# [Epoch 191/200] [Train_Loss: 0.524486 / Valid_Loss: 0.589080]
# [Epoch 191/200] [Accuracy : 0.741500]
# [Epoch 192/200] [Train_Loss: 0.541104 / Valid_Loss: 0.589053]
# [Epoch 192/200] [Accuracy : 0.740375]
# [Epoch 193/200] [Train_Loss: 0.553562 / Valid_Loss: 0.590560]
# [Epoch 193/200] [Accuracy : 0.737912]
# [Epoch 194/200] [Train_Loss: 0.529738 / Valid_Loss: 0.595121]
# [Epoch 194/200] [Accuracy : 0.736563]
# [Epoch 195/200] [Train_Loss: 0.538488 / Valid_Loss: 0.593333]
# [Epoch 195/200] [Accuracy : 0.738225]
# [Epoch 196/200] [Train_Loss: 0.538871 / Valid_Loss: 0.591922]
# [Epoch 196/200] [Accuracy : 0.737263]
# [Epoch 197/200] [Train_Loss: 0.519138 / Valid_Loss: 0.588546]
# [Epoch 197/200] [Accuracy : 0.738725]
# [Epoch 198/200] [Train_Loss: 0.548557 / Valid_Loss: 0.594960]
# [Epoch 198/200] [Accuracy : 0.736400]
# [Epoch 199/200] [Train_Loss: 0.520661 / Valid_Loss: 0.588424]
# [Epoch 199/200] [Accuracy : 0.734800]
# [Epoch 200/200] [Train_Loss: 0.537180 / Valid_Loss: 0.584780]
# [Epoch 200/200] [Accuracy : 0.742800]

# %%
# 모델 평가

def test_model(model, PATH):
    model = torch.load(PATH + 'model.pt')

    #---------------------- 모델 시험 ----------------------#
    model.eval()
    total    = 0.0
    accuracy = 0.0

    for batch_idx, data in enumerate(test_dataloader):
        x_test, y_test = data
        t_hat  = model(x_test)
        _, predicted = torch.max(t_hat.data, 1)
        total    += y_test.size(0)
        accuracy += (predicted == y_test).sum().item()

    accuracy = accuracy / total
    #-------------------------------------------------------#
    print(accuracy)

# %%
# 혼동 행렬

from sklearn.metrics import classification_report, confusion_matrix

def draw_confusion_matrix(model, xt, yt, PATH):
    y_pred = []
    y_true = []

    model.eval()
    y_hat  = model(xt)
    output = (torch.max(torch.exp(y_hat), 1)[1]).data.cpu().numpy()
    y_pred.extend(output)
    labels = yt.data.cpu().numpy()
    y_true.extend(labels)

    # 분류 항목
    classes = ('Normal', 'Type1', 'Type2','Type3')

    # Confusion Matrix 생성
    plt.figure(figsize=(7, 5))
    dlen  = float(len(xt))
    cm    = confusion_matrix(y_true, y_pred)
    df_cm = pd.DataFrame(cm / dlen,
                         index  =[i for i in classes],
                         columns=[i for i in classes])

    sns.heatmap(df_cm, annot=True, cmap=plt.cm.Blues)
    plt.title("Confusion Matrix", size=24, fontweight='bold')
    plt.xlabel("Predicted Label", size=16)
    plt.ylabel("Actual Label",   size=16)
    plt.rc('xtick', labelsize=12)
    plt.rc('ytick', labelsize=12)
    plt.yticks(rotation=0)
    plt.savefig(PATH + 'cm_output.png')

# %%
# 손실 그래프

def plot_loss_graph(loss_values, loss_values_v, PATH):
    plt.figure()
    plt.plot(loss_values)
    plt.plot(loss_values_v)
    plt.title("Training & Validation Loss")
    plt.ylabel("loss",  fontsize="large")
    plt.xlabel("epoch", fontsize="large")
    plt.legend(["train", "validation"])
    plt.tight_layout()
    plt.savefig(PATH + 'lossplot_output.png')

# %%
PATH ='save/DNN/'
test_model(DNN_model, PATH)
draw_confusion_matrix(DNN_model, x_test, y_test, PATH)
plot_loss_graph(DNN_loss_values, DNN_loss_values_v, PATH)
# Out:
# 0.7703214285714286

# %%
model = torch.load('save/DNN/model.pt')
model.eval()
# Out:
# KAMP_DNN(
#   (layer1): Linear(in_features=4, out_features=100, bias=True)
#   (layer2): Linear(in_features=100, out_features=100, bias=True)
#   (layer3): Linear(in_features=100, out_features=100, bias=True)
#   (layer4): Linear(in_features=100, out_features=4, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (relu): ReLU()
# )
